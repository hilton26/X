# %% [markdown]
# # Derivative Cover Reporting

# %% [markdown]
# ### Input:
#
# \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Daily\py_reports, "downloader" tab
#
# ### Dependencies:
# C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/derv_checker_downloading.ipynb "dervs" tab
#
# C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/derv_checker_compiling.ipynb "dervs" tab

# %%
# define the report function
def derv_check():
    import time
    start_time_roundtrip = time.time()
    
    # libraries, libraries!
    import os, schedule
    import pandas as pd
    import subprocess
    from datetime import datetime
    from constants import pthPy, pthEXPORTS, frcv_file, pthDaily, dc_do_nb, dc_co_nb, dc_su_nb, dc_fr_nb
    from utilities import timediff, prior_working_day
    
    #check if the report already exists, if yes, exit the script
    df2      = pd.read_excel(pthPy, sheet_name = "arc", header = None, usecols = "E").dropna()
    rptDate  = df2.iloc[1, 0] if isinstance(df2.iloc[1, 0], datetime) else prior_working_day(datetime.today()) # prior working day or report date override given today's date
    
    filename = os.path.join(pthEXPORTS, f'Derv {rptDate.strftime("%d%b%Y")}.xlsx')
    df_frcv  = pd.read_excel(frcv_file, sheet_name = "Summary", header = None, usecols = "C", nrows  = 1) # for last date in Free Cover.xlsm
    
    if rptDate.date() == datetime.strptime(df_frcv.iloc[0, 0][15:26],"%d %b %Y").date():
        print(f'{datetime.now().strftime("%Hh%M:%Ss %a %d %b %Y")}: \
{frcv_file.removeprefix(pthEXPORTS)} for {rptDate.strftime("%A %d %B %Y")} \
was completed {time.ctime(os.path.getmtime(frcv_file))}')
        return
    else:
        try:
            # %run "$dc_do_nb" # downloading
            # %run "$dc_co_nb" # compiling
            # %run "$dc_su_nb" # summarising
            # %run "$dc_fr_nb" # free cover reporting file
            
            if os.path.isfile(filename):
                print(f'{datetime.now().strftime("%Hh%M:%Ss %a %d %b %Y")}: \
                {filename.removeprefix(pthEXPORTS)} was completed at {time.ctime(os.path.getmtime(filename))}','\n')

        except Exception as e:
            print(e)

        print("\n", f"{timediff(start_time_roundtrip, time.time())} roundtrip time to download and \
complete {rptDate.strftime('%d %b %Y')} derivative cover reports")

# %%
# list the frequency of runs

from datetime import datetime, timedelta

# list of times every 15 minutes from 8:45 AM to 17:30
start = datetime.strptime("08:23", "%H:%M")
end = datetime.strptime("18:30", "%H:%M")
increment = 15   # every 15 minutes

times = []
current = start
while current <= end:
    times.append(current.strftime("%H:%M"))
    current += timedelta(minutes=increment)

print((", ").join(times))
# Out:
# 08:23, 08:38, 08:53, 09:08, 09:23, 09:38, 09:53, 10:08, 10:23, 10:38, 10:53, 11:08, 11:23, 11:38, 11:53, 12:08, 12:23, 12:38, 12:53, 13:08, 13:23, 13:38, 13:53, 14:08, 14:23, 14:38, 14:53, 15:08, 15:23, 15:38, 15:53, 16:08, 16:23, 16:38, 16:53, 17:08, 17:23, 17:38, 17:53, 18:08, 18:23

# %%
# scheduler    https://pypi.org/project/schedule/
import schedule, time
         
for t in times:
    schedule.every().monday.   at(t).do(lambda: derv_check())
    schedule.every().tuesday.  at(t).do(lambda: derv_check())
    schedule.every().wednesday.at(t).do(lambda: derv_check())
    schedule.every().thursday. at(t).do(lambda: derv_check())
    schedule.every().friday.   at(t).do(lambda: derv_check())

while True:
    schedule.run_pending()
    time.sleep(10)
# Out:
# 10h23:14s Fri 31 Jul 2026: \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Daily\Free Cover.xlsm for Wednesday 29 July 2026 was completed Thu Jul 30 11:36:46 2026
# 10h38:07s Fri 31 Jul 2026: \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Daily\Free Cover.xlsm for Wednesday 29 July 2026 was completed Thu Jul 30 11:36:46 2026
# 10h53:10s Fri 31 Jul 2026: \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Daily\Free Cover.xlsm for Wednesday 29 July 2026 was completed Thu Jul 30 11:36:46 2026
# 11h08:03s Fri 31 Jul 2026: \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Daily\Free Cover.xlsm for Wednesday 29 July 2026 was completed Thu Jul 30 11:36:46 2026
#
#
# ################################################
# #                                              #
# #   START 1/4 derv_checker_downloading.ipynb   #
# #                                              #
# ################################################
#
#
# Importing libraries and setting paths for derv_checker_downloading.ipynb ...
#  6.2sec importing libraries and setting paths for derv_checker_downloading.ipynb
#
# Deriving file names ...
#
# Wednesday 29 Jul 2026 for 153 funds:
#  3BBCIINC,ABMMBND,ADRRC,ADVMB,AFGBAL,AFLBAL,AFLMMF,AMMARF,AMPBQP,ASBTOS,ASHFLX,BCICEF,BCIFIF,BPROV,CCNPF,CMPFCASH,CMPFFLEX,CMPFINC,CSIRBQP,ECICBALC,ELCIPF,ENGENIP,ENGENMBF,FEMPBF,GACASH,GAEMBF,GEMSMEDC,GMRETF,GMRETF2,GRFINV,GTCWP2,HOLADC,HOLDINC,HOLEQU,HOLIDC,HOLMMF,HOLYPF,HOSMED,IJGCOR,IJGIPF,IMPALA,IMPBAL_C,IMPREF_C,IPIPF,ISPFP,LEZAFFI,LEZALDI,LPIIFTAA,MASAINC,MASAINRF,MASAMMF,MASASI,MASASIRF,MEDINC,MGFYQP,MOMBBF,MOMBBRF,MOMFLX,MOMFXB,MOMIPF,MOMPRET,MOMTAAHI,MOMTAALI,MOMTAAMI,MULTICH,MWPFEQU,MWPFILB,MYQIP,NEDMED,NESEQU,NFMWEQU,NFMWAGG,NGKINC,OMMAIF,PABS,PANDA,PBFETF,PBNDQ,PCBF,PCCEF,PCEQTF,PCGEARF,PCGEF,PCSHQ,PEQ,PEQF,PETFIP,PEYF,PFFIF,PGCBF,PGCEF,PGIPFA,PGPCEM_C,PGPCGE_C,PGPGARF,PGPGBF_C,PGPGIF_C,PGPRF_C,PICPROV,PIF,PIMBAL,PIMEVO,PIMIDF,PIPF,PIPFP,PLMED,PLPRNA,PMMF,POIF_C,PORFIP,PPEF,PPOS,PPSBAL_C,PPSFLEX,PPSNAM,PPSRBNQ,PPWEQU,PRPABF,PRPDBF,PSIF,PSILB,PSPAM,PSSPFEQU,PSTIF,PTIF,QIFFGIF,SAAMCAU,SAAMINC,SAAMMOD,SABCCSHF,SDINCPM,SILAIF,SILEQF,SISLP,SMMAIF,SMMIBF,SMMILP,SMMRRF,SNPFEQU,SSLSP,STBFIP,TRFINC,TRFWLTH,UCT3YQ,UCTINC,UCTRFBAL,UCTRFINC,UNISABAL,USAIPF,UWRFCON,UWRFGRO,VMPTAA_C,PWMIPF_P
#
#  A summary sheet is required
#
# 0.0sec deriving file names
#
# Downloading and then saving holdings data ...
#   PARN (153) 29Jul2026.csv already exists
#
#  PARN (153) 29Jul2026.csv
#
#
# 0.0sec downloading and then saving holdings data
#
# Downloading and then saving derivative data ...
#   DERV (153) 29Jul2026.csv already exists
# 0.0sec downloading and then saving derivative data
#
# Getting the reporting date and latest downloaded holdings and derivatives files
#
#  Expected downloads:
#   C:\Users\hilton.netta\Downloads\PARN (153) 29Jul2026.csv which exists
#   C:\Users\hilton.netta\Downloads\DERV (153) 29Jul2026.csv which exists
#  A summary sheet is required
#
# 0.0sec getting the reporting date and latest downloaded holdings and derivatives files
#
# 6.2sec downloading holdings and derivative metrics. Next step is compiling.
#
#
#
# ################################################
# #                                              #
# #    END 1/4 derv_checker_downloading.ipynb    #
# #                                              #
# ################################################
#
#
#
#
# ################################################
# #                                              #
# #    START 2/4 derv_checker_compiling.ipynb    #
# #                                              #
# ################################################
#
#
# Importing libraries and constants ...
#  0.4sec importing libraries and constants
#
# Getting the reporting date and latest downloaded holdings and derivatives files...
#
#  Thursday 30 Jul 2026 for 153 funds:
#  3BBCIINC,ABMMBND,ADRRC,ADVMB,AFGBAL,AFLBAL,AFLMMF,AMMARF,AMPBQP,ASBTOS,ASHFLX,BCICEF,BCIFIF,BPROV,CCNPF,CMPFCASH,CMPFFLEX,CMPFINC,CSIRBQP,ECICBALC,ELCIPF,ENGENIP,ENGENMBF,FEMPBF,GACASH,GAEMBF,GEMSMEDC,GMRETF,GMRETF2,GRFINV,GTCWP2,HOLADC,HOLDINC,HOLEQU,HOLIDC,HOLMMF,HOLYPF,HOSMED,IJGCOR,IJGIPF,IMPALA,IMPBAL_C,IMPREF_C,IPIPF,ISPFP,LEZAFFI,LEZALDI,LPIIFTAA,MASAINC,MASAINRF,MASAMMF,MASASI,MASASIRF,MEDINC,MGFYQP,MOMBBF,MOMBBRF,MOMFLX,MOMFXB,MOMIPF,MOMPRET,MOMTAAHI,MOMTAALI,MOMTAAMI,MULTICH,MWPFEQU,MWPFILB,MYQIP,NEDMED,NESEQU,NFMWEQU,NFMWAGG,NGKINC,OMMAIF,PABS,PANDA,PBFETF,PBNDQ,PCBF,PCCEF,PCEQTF,PCGEARF,PCGEF,PCSHQ,PEQ,PEQF,PETFIP,PEYF,PFFIF,PGCBF,PGCEF,PGIPFA,PGPCEM_C,PGPCGE_C,PGPGARF,PGPGBF_C,PGPGIF_C,PGPRF_C,PICPROV,PIF,PIMBAL,PIMEVO,PIMIDF,PIPF,PIPFP,PLMED,PLPRNA,PMMF,POIF_C,PORFIP,PPEF,PPOS,PPSBAL_C,PPSFLEX,PPSNAM,PPSRBNQ,PPWEQU,PRPABF,PRPDBF,PSIF,PSILB,PSPAM,PSSPFEQU,PSTIF,PTIF,QIFFGIF,SAAMCAU,SAAMINC,SAAMMOD,SABCCSHF,SDINCPM,SILAIF,SILEQF,SISLP,SMMAIF,SMMIBF,SMMILP,SMMRRF,SNPFEQU,SSLSP,STBFIP,TRFINC,TRFWLTH,UCT3YQ,UCTINC,UCTRFBAL,UCTRFINC,UNISABAL,USAIPF,UWRFCON,UWRFGRO,VMPTAA_C,PWMIPF_P
#
#  Expected downloads:
#   C:\Users\hilton.netta\Downloads\PARN (153) 30Jul2026.csv (holdings) which exists
#   C:\Users\hilton.netta\Downloads\DERV (153) 30Jul2026.csv (derivatives) which exists
#  A summary sheet is required
#
#
# 2.9sec getting the reporting date and latest downloaded holdings and derivatives files
#
# Creating holdings and deltas dataframes ...
#   0 "UNKNOWN" securities identified and renamed:
#
# 0.5sec creating holdings and deltas dataframes
#
# Recalculating and saving fund Total Market Value percentages ...
# 0it [00:00, ?it/s]
#   0%|          | 0/8226 [00:00<?, ?it/s]
#  1.5sec recalculating and saving fund Total Market Value percentages
#
#
# Determining the derivative cover reports already completed for Thu 30 Jul 2026 ...
#
# 0 completed:
#
#
# 153 remaining:
#  3BBCIINC,ABMMBND,ADRRC,ADVMB,AFGBAL,AFLBAL,AFLMMF,AMMARF,AMPBQP,ASBTOS,ASHFLX,BCICEF,BCIFIF,BPROV,CCNPF,CMPFCASH,CMPFFLEX,CMPFINC,CSIRBQP,ECICBALC,ELCIPF,ENGENIP,ENGENMBF,FEMPBF,GACASH,GAEMBF,GEMSMEDC,GMRETF,GMRETF2,GRFINV,GTCWP2,HOLADC,HOLDINC,HOLEQU,HOLIDC,HOLMMF,HOLYPF,HOSMED,IJGCOR,IJGIPF,IMPALA,IMPBAL_C,IMPREF_C,IPIPF,ISPFP,LEZAFFI,LEZALDI,LPIIFTAA,MASAINC,MASAINRF,MASAMMF,MASASI,MASASIRF,MEDINC,MGFYQP,MOMBBF,MOMBBRF,MOMFLX,MOMFXB,MOMIPF,MOMPRET,MOMTAAHI,MOMTAALI,MOMTAAMI,MULTICH,MWPFEQU,MWPFILB,MYQIP,NEDMED,NESEQU,NFMWAGG,NFMWEQU,NGKINC,OMMAIF,PABS,PANDA,PBFETF,PBNDQ,PCBF,PCCEF,PCEQTF,PCGEARF,PCGEF,PCSHQ,PEQ,PEQF,PETFIP,PEYF,PFFIF,PGCBF,PGCEF,PGIPFA,PGPCEM_C,PGPCGE_C,PGPGARF,PGPGBF_C,PGPGIF_C,PGPRF_C,PICPROV,PIF,PIMBAL,PIMEVO,PIMIDF,PIPF,PIPFP,PLMED,PLPRNA,PMMF,POIF_C,PORFIP,PPEF,PPOS,PPSBAL_C,PPSFLEX,PPSNAM,PPSRBNQ,PPWEQU,PRPABF,PRPDBF,PSIF,PSILB,PSPAM,PSSPFEQU,PSTIF,PTIF,PWMIPF_P,QIFFGIF,SAAMCAU,SAAMINC,SAAMMOD,SABCCSHF,SDINCPM,SILAIF,SILEQF,SISLP,SMMAIF,SMMIBF,SMMILP,SMMRRF,SNPFEQU,SSLSP,STBFIP,TRFINC,TRFWLTH,UCT3YQ,UCTINC,UCTRFBAL,UCTRFINC,UNISABAL,USAIPF,UWRFCON,UWRFGRO,VMPTAA_C
#
#
# 0.0sec determining the derivative cover reports already completed for Thu 30 Jul 2026: 0 completed, 153 remaining
#
# Compiling derivative calculation files for 153 funds at 30 Jul 2026
#   0%|          | 0/153 [00:00<?, ?it/s]
#  59.7sec compiling derivative calculation files for 153 funds at 30 Jul 2026
#
# Saving the 153 fund derivative calculation files to the Derivative Cover folder ...
#   0%|          | 0/153 [00:00<?, ?it/s]
# 21.4sec saving the 153 fund derivative calculation files to Derivative Cover folder
#
# Deleting contents of the temporary folder ...
#   0%|          | 0/153 [00:00<?, ?it/s]
# 0.1sec deleting contents of the temporary folder completed
#
# 1min 26.7sec total time to compile and save 153 derivative calculation files for 30 Jul 2026
#
#
# ################################################
# #                                              #
# #     END 2/4 derv_checker_compiling.ipynb     #
# #                                              #
# ################################################
#
#
#
#
# ##############################################
# #                                            #
# #  START 3/4 derv_checker_summarising.ipynb  #
# #                                            #
# ##############################################
#
#
# Importing libraries to summarise the derivative calcs ...
#  0.6sec importing libraries to summarise the derivative calcs
#
# Getting the reporting date and names of completed derivative files ...
#  Get scandir() of derivative calcs folder for Thu 30 July 2026
# 3765it [00:00, 457858.93it/s]
#  153 funds
#  0.0sec to get scandir() of derivative calcs folder for Thu 30 July 2026
#  Thursday 30 Jul 2026 for 153 funds: 3BBCIINC, ABMMBND, ADRRC, ADVMB, AFGBAL, AFLBAL, AFLMMF, AMMARF, AMPBQP, ASBTOS, ASHFLX, BCICEF, BCIFIF, BPROV, CCNPF, CMPFCASH, CMPFFLEX, CMPFINC, CSIRBQP, ECICBALC, ELCIPF, ENGENIP, ENGENMBF, FEMPBF, GACASH, GAEMBF, GEMSMEDC, GMRETF, GMRETF2, GRFINV, GTCWP2, HOLADC, HOLDINC, HOLEQU, HOLIDC, HOLMMF, HOLYPF, HOSMED, IJGCOR, IJGIPF, IMPALA, IMPBAL_C, IMPREF_C, IPIPF, ISPFP, LEZAFFI, LEZALDI, LPIIFTAA, MASAINC, MASAINRF, MASAMMF, MASASI, MASASIRF, MEDINC, MGFYQP, MOMBBF, MOMBBRF, MOMFLX, MOMFXB, MOMIPF, MOMPRET, MOMTAAHI, MOMTAALI, MOMTAAMI, MULTICH, MWPFEQU, MWPFILB, MYQIP, NEDMED, NESEQU, NFMWEQU, NFMWAGG, NGKINC, OMMAIF, PABS, PANDA, PBFETF, PBNDQ, PCBF, PCCEF, PCEQTF, PCGEARF, PCGEF, PCSHQ, PEQ, PEQF, PETFIP, PEYF, PFFIF, PGCBF, PGCEF, PGIPFA, PGPCEM_C, PGPCGE_C, PGPGARF, PGPGBF_C, PGPGIF_C, PGPRF_C, PICPROV, PIF, PIMBAL, PIMEVO, PIMIDF, PIPF, PIPFP, PLMED, PLPRNA, PMMF, POIF_C, PORFIP, PPEF, PPOS, PPSBAL_C, PPSFLEX, PPSNAM, PPSRBNQ, PPWEQU, PRPABF, PRPDBF, PSIF, PSILB, PSPAM, PSSPFEQU, PSTIF, PTIF, QIFFGIF, SAAMCAU, SAAMINC, SAAMMOD, SABCCSHF, SDINCPM, SILAIF, SILEQF, SISLP, SMMAIF, SMMIBF, SMMILP, SMMRRF, SNPFEQU, SSLSP, STBFIP, TRFINC, TRFWLTH, UCT3YQ, UCTINC, UCTRFBAL, UCTRFINC, UNISABAL, USAIPF, UWRFCON, UWRFGRO, VMPTAA_C, PWMIPF_P
#
#  A summary sheet is required
#  153 completed derivative calculation files at Thursday 30 July 2026
#
#  3.5sec getting the reporting date and names of completed derivative files
#
# Populating the summary dataframe with 153 funds for Thursday 30 July 2026 ...
# 100%|████████████████████████████████████████████████████████████████████████████| 153/153 [00:42<00:00,  3.59it/s]
#  42.7sec populating the summary dataframe with 153 funds for Thursday 30 July 2026
#
# Sorting and then saving the summary dataframe with 153 funds for Thursday 30 July 2026 ...
#  0.5sec sorting and then saving the summary dataframe with 153 funds for Thursday 30 July 2026
#
# Writing the dataframe to a sheet ...
#   0 "UNKNOWN" securities found and amended:
#   0 "No data" funds:
#
# Summary file:
#  \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Derivative Cover\Derv 30Jul2026.xlsx
#
# 10.2sec writing the dataframe to a sheet
# Prettifying and adding links to the summary sheet with xlwings ...
#   Adding investment team names and links to fund mandates and calculation sheets
#   0%|                                                                                      | 0/153 [00:00<?, ?it/s]C:\Users\hilton.netta\AppData\Local\Temp\ipykernel_19416\928037208.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   shtS['A' + str(index + 2)].add_hyperlink(fr'{pthEXPORTS}\{row[0]} Derv Calc {rptDate.strftime("%d%b%Y")}.xlsx', f'{row[0]}') # link to calc sheet
# C:\Users\hilton.netta\AppData\Local\Temp\ipykernel_19416\928037208.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   shtS['W' + str(index + 2)].add_hyperlink(fr'{pthMandates}\{row[0]} Rules.docx',f'{row[0]}')                            # link to fund mandate
# 100%|████████████████████████████████████████████████████████████████████████████| 153/153 [00:45<00:00,  3.40it/s]
#   45.0sec adding investment team names and links to fund mandates and calculation sheets
#
#    Adding conditional formats for values that are negative or exceed 100% of NAV; 2907 = 153 funds x 19 columns
# 100%|██████████████████████████████████████████████████████████████████████████| 2907/2907 [01:01<00:00, 46.90it/s]
#   1min 2.1sec adding conditional formats for values that are negative or exceed 100% of NAV
#   \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Derivative Cover\Derv 30Jul2026.xlsx
#
# 1min 56.2sec prettifying and adding links to the summary sheet with xlwings
#
# Saving the summary dataframe to the derv_summary.xlsx template; 2926 = (153 funds + 1) x 19 columns
# 100%|██████████████████████████████████████████████████████████████████████████| 2926/2926 [01:05<00:00, 44.49it/s]
#   \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Daily\derv_summary.xlsx
#
#  1min 27.9sec saving the summary dataframe to the derv_summary.xlsx template
#
# Deleting contents of the local temporary folder ...
# 0it [00:00, ?it/s]
# 0.0sec deleting contents of the local temporary folder completed
#
# 4min 21.7sec roundtrip time to summarise derivative calcs
#
#
#
# ##############################################
# #                                            #
# #   END 3/4 derv_checker_summarising.ipynb   #
# #                                            #
# ##############################################
#
#
#
#
# ##############################################
# #                                            #
# #      START 4/4 DERV_CHECKER_FREECOVER      #
# #                                            #
# ##############################################
#
#
# Importing libraries and constants for the free cover report ...
#  0.4sec importing libraries and constants for the free cover report
#
# Getting the reporting date and the comparative prior reporting date ...
#
#  Thu 30 Jul 2026 current report date
#  Wed 29 Jul 2026 prior report date
#  10.0% threshold
#
#  2.6sec getting the reporting date and the comparative prior reporting date
#
# Dataframing current and prior working day derivative summary files ...
#
#   \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Derivative Cover\Derv 29Jul2026.xlsx
#   \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Derivative Cover\Derv 30Jul2026.xlsx
#
#  0.8sec dataframing current and prior working day derivative summary files
#
# Dataframing current and prior day derivative summaries ...
#
#
# 4 cols: ['Derivative Cover Calcs 30Jul2026', 'UT?', '#', 'Cash Cover']
# 2 cols: ['Fund Code', 'Fund Name']
# 6 cols: ['Derivative Cover Calcs 30Jul2026', 'UT?', '#', 'Cash Cover', 'Fund Code', 'Fund Name']
#
#
# 4 cols: ['Derivative Cover Calcs 29Jul2026', 'UT?', '#', 'Cash Cover']
# 10 cols: ['Derivative Cover Calcs 30Jul2026', 'UT?_x', '#_x', 'Cash Cover_x', 'Fund Code', 'Fund Name', 'Derivative Cover Calcs 29Jul2026', 'UT?_y', '#_y', 'Cash Cover_y']
#
#
# 6 cols: ['Derivative Cover Calcs 30Jul2026', 'UT?_x', '#_x', 'Cash Cover_x', 'Fund Name', 'Cash Cover_y']
#  0.0sec dataframing current and prior day derivative summaries
#
# Saving the newest Free Cover.xlsm file ...
#
#  23.9sec saving the newest \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Daily\Free Cover.xlsm
#
# 27.9sec roundtrip time for free cover file
#
#
# ##############################################
# #                                            #
# #       END 4/4 DERV_CHECKER_FREECOVER       #
# #                                            #
# ##############################################
#
#
# 11h29:31s Fri 31 Jul 2026:                 \Derv 29Jul2026.xlsx was completed at Thu Jul 30 09:53:06 2026
#
#
#  6min 27.4sec roundtrip time to download and complete 29 Jul 2026 derivative cover reports
#
#
# ################################################
# #                                              #
# #   START 1/4 derv_checker_downloading.ipynb   #
# #                                              #
# ################################################
#
#
# Importing libraries and setting paths for derv_checker_downloading.ipynb ...
#  7.4sec importing libraries and setting paths for derv_checker_downloading.ipynb
#
# Deriving file names ...
#
# Wednesday 29 Jul 2026 for 153 funds:
#  3BBCIINC,ABMMBND,ADRRC,ADVMB,AFGBAL,AFLBAL,AFLMMF,AMMARF,AMPBQP,ASBTOS,ASHFLX,BCICEF,BCIFIF,BPROV,CCNPF,CMPFCASH,CMPFFLEX,CMPFINC,CSIRBQP,ECICBALC,ELCIPF,ENGENIP,ENGENMBF,FEMPBF,GACASH,GAEMBF,GEMSMEDC,GMRETF,GMRETF2,GRFINV,GTCWP2,HOLADC,HOLDINC,HOLEQU,HOLIDC,HOLMMF,HOLYPF,HOSMED,IJGCOR,IJGIPF,IMPALA,IMPBAL_C,IMPREF_C,IPIPF,ISPFP,LEZAFFI,LEZALDI,LPIIFTAA,MASAINC,MASAINRF,MASAMMF,MASASI,MASASIRF,MEDINC,MGFYQP,MOMBBF,MOMBBRF,MOMFLX,MOMFXB,MOMIPF,MOMPRET,MOMTAAHI,MOMTAALI,MOMTAAMI,MULTICH,MWPFEQU,MWPFILB,MYQIP,NEDMED,NESEQU,NFMWEQU,NFMWAGG,NGKINC,OMMAIF,PABS,PANDA,PBFETF,PBNDQ,PCBF,PCCEF,PCEQTF,PCGEARF,PCGEF,PCSHQ,PEQ,PEQF,PETFIP,PEYF,PFFIF,PGCBF,PGCEF,PGIPFA,PGPCEM_C,PGPCGE_C,PGPGARF,PGPGBF_C,PGPGIF_C,PGPRF_C,PICPROV,PIF,PIMBAL,PIMEVO,PIMIDF,PIPF,PIPFP,PLMED,PLPRNA,PMMF,POIF_C,PORFIP,PPEF,PPOS,PPSBAL_C,PPSFLEX,PPSNAM,PPSRBNQ,PPWEQU,PRPABF,PRPDBF,PSIF,PSILB,PSPAM,PSSPFEQU,PSTIF,PTIF,QIFFGIF,SAAMCAU,SAAMINC,SAAMMOD,SABCCSHF,SDINCPM,SILAIF,SILEQF,SISLP,SMMAIF,SMMIBF,SMMILP,SMMRRF,SNPFEQU,SSLSP,STBFIP,TRFINC,TRFWLTH,UCT3YQ,UCTINC,UCTRFBAL,UCTRFINC,UNISABAL,USAIPF,UWRFCON,UWRFGRO,VMPTAA_C,PWMIPF_P
#
#  A summary sheet is required
#
# 0.0sec deriving file names
#
# Downloading and then saving holdings data ...
#   PARN (153) 29Jul2026.csv already exists
#
#  PARN (153) 29Jul2026.csv
#
#
# 0.0sec downloading and then saving holdings data
#
# Downloading and then saving derivative data ...
#   DERV (153) 29Jul2026.csv already exists
# 0.0sec downloading and then saving derivative data
#
# Getting the reporting date and latest downloaded holdings and derivatives files
#
#  Expected downloads:
#   C:\Users\hilton.netta\Downloads\PARN (153) 29Jul2026.csv which exists
#   C:\Users\hilton.netta\Downloads\DERV (153) 29Jul2026.csv which exists
#  A summary sheet is required
#
# 0.0sec getting the reporting date and latest downloaded holdings and derivatives files
#
# 7.5sec downloading holdings and derivative metrics. Next step is compiling.
#
#
#
# ################################################
# #                                              #
# #    END 1/4 derv_checker_downloading.ipynb    #
# #                                              #
# ################################################
#
#
#
#
# ################################################
# #                                              #
# #    START 2/4 derv_checker_compiling.ipynb    #
# #                                              #
# ################################################
#
#
# Importing libraries and constants ...
#  0.0sec importing libraries and constants
#
# Getting the reporting date and latest downloaded holdings and derivatives files...
#
#  Thursday 30 Jul 2026 for 153 funds:
#  3BBCIINC,ABMMBND,ADRRC,ADVMB,AFGBAL,AFLBAL,AFLMMF,AMMARF,AMPBQP,ASBTOS,ASHFLX,BCICEF,BCIFIF,BPROV,CCNPF,CMPFCASH,CMPFFLEX,CMPFINC,CSIRBQP,ECICBALC,ELCIPF,ENGENIP,ENGENMBF,FEMPBF,GACASH,GAEMBF,GEMSMEDC,GMRETF,GMRETF2,GRFINV,GTCWP2,HOLADC,HOLDINC,HOLEQU,HOLIDC,HOLMMF,HOLYPF,HOSMED,IJGCOR,IJGIPF,IMPALA,IMPBAL_C,IMPREF_C,IPIPF,ISPFP,LEZAFFI,LEZALDI,LPIIFTAA,MASAINC,MASAINRF,MASAMMF,MASASI,MASASIRF,MEDINC,MGFYQP,MOMBBF,MOMBBRF,MOMFLX,MOMFXB,MOMIPF,MOMPRET,MOMTAAHI,MOMTAALI,MOMTAAMI,MULTICH,MWPFEQU,MWPFILB,MYQIP,NEDMED,NESEQU,NFMWEQU,NFMWAGG,NGKINC,OMMAIF,PABS,PANDA,PBFETF,PBNDQ,PCBF,PCCEF,PCEQTF,PCGEARF,PCGEF,PCSHQ,PEQ,PEQF,PETFIP,PEYF,PFFIF,PGCBF,PGCEF,PGIPFA,PGPCEM_C,PGPCGE_C,PGPGARF,PGPGBF_C,PGPGIF_C,PGPRF_C,PICPROV,PIF,PIMBAL,PIMEVO,PIMIDF,PIPF,PIPFP,PLMED,PLPRNA,PMMF,POIF_C,PORFIP,PPEF,PPOS,PPSBAL_C,PPSFLEX,PPSNAM,PPSRBNQ,PPWEQU,PRPABF,PRPDBF,PSIF,PSILB,PSPAM,PSSPFEQU,PSTIF,PTIF,QIFFGIF,SAAMCAU,SAAMINC,SAAMMOD,SABCCSHF,SDINCPM,SILAIF,SILEQF,SISLP,SMMAIF,SMMIBF,SMMILP,SMMRRF,SNPFEQU,SSLSP,STBFIP,TRFINC,TRFWLTH,UCT3YQ,UCTINC,UCTRFBAL,UCTRFINC,UNISABAL,USAIPF,UWRFCON,UWRFGRO,VMPTAA_C,PWMIPF_P
#
#  Expected downloads:
#   C:\Users\hilton.netta\Downloads\PARN (153) 30Jul2026.csv (holdings) which exists
#   C:\Users\hilton.netta\Downloads\DERV (153) 30Jul2026.csv (derivatives) which exists
#  A summary sheet is required
#
#
# 5.3sec getting the reporting date and latest downloaded holdings and derivatives files
#
# Creating holdings and deltas dataframes ...
#   0 "UNKNOWN" securities identified and renamed:
#
# 1.1sec creating holdings and deltas dataframes
#
# Recalculating and saving fund Total Market Value percentages ...
# 0it [00:00, ?it/s]
#   0%|          | 0/8226 [00:00<?, ?it/s]
#  2.0sec recalculating and saving fund Total Market Value percentages
#
#
# Determining the derivative cover reports already completed for Thu 30 Jul 2026 ...
#
# 0 completed:
#
#
# 153 remaining:
#  3BBCIINC,ABMMBND,ADRRC,ADVMB,AFGBAL,AFLBAL,AFLMMF,AMMARF,AMPBQP,ASBTOS,ASHFLX,BCICEF,BCIFIF,BPROV,CCNPF,CMPFCASH,CMPFFLEX,CMPFINC,CSIRBQP,ECICBALC,ELCIPF,ENGENIP,ENGENMBF,FEMPBF,GACASH,GAEMBF,GEMSMEDC,GMRETF,GMRETF2,GRFINV,GTCWP2,HOLADC,HOLDINC,HOLEQU,HOLIDC,HOLMMF,HOLYPF,HOSMED,IJGCOR,IJGIPF,IMPALA,IMPBAL_C,IMPREF_C,IPIPF,ISPFP,LEZAFFI,LEZALDI,LPIIFTAA,MASAINC,MASAINRF,MASAMMF,MASASI,MASASIRF,MEDINC,MGFYQP,MOMBBF,MOMBBRF,MOMFLX,MOMFXB,MOMIPF,MOMPRET,MOMTAAHI,MOMTAALI,MOMTAAMI,MULTICH,MWPFEQU,MWPFILB,MYQIP,NEDMED,NESEQU,NFMWAGG,NFMWEQU,NGKINC,OMMAIF,PABS,PANDA,PBFETF,PBNDQ,PCBF,PCCEF,PCEQTF,PCGEARF,PCGEF,PCSHQ,PEQ,PEQF,PETFIP,PEYF,PFFIF,PGCBF,PGCEF,PGIPFA,PGPCEM_C,PGPCGE_C,PGPGARF,PGPGBF_C,PGPGIF_C,PGPRF_C,PICPROV,PIF,PIMBAL,PIMEVO,PIMIDF,PIPF,PIPFP,PLMED,PLPRNA,PMMF,POIF_C,PORFIP,PPEF,PPOS,PPSBAL_C,PPSFLEX,PPSNAM,PPSRBNQ,PPWEQU,PRPABF,PRPDBF,PSIF,PSILB,PSPAM,PSSPFEQU,PSTIF,PTIF,PWMIPF_P,QIFFGIF,SAAMCAU,SAAMINC,SAAMMOD,SABCCSHF,SDINCPM,SILAIF,SILEQF,SISLP,SMMAIF,SMMIBF,SMMILP,SMMRRF,SNPFEQU,SSLSP,STBFIP,TRFINC,TRFWLTH,UCT3YQ,UCTINC,UCTRFBAL,UCTRFINC,UNISABAL,USAIPF,UWRFCON,UWRFGRO,VMPTAA_C
#
#
# 0.0sec determining the derivative cover reports already completed for Thu 30 Jul 2026: 0 completed, 153 remaining
#
# Compiling derivative calculation files for 153 funds at 30 Jul 2026
#   0%|          | 0/153 [00:00<?, ?it/s]
#  1min 1.7sec compiling derivative calculation files for 153 funds at 30 Jul 2026
#
# Saving the 153 fund derivative calculation files to the Derivative Cover folder ...
#   0%|          | 0/153 [00:00<?, ?it/s]
# 16.0sec saving the 153 fund derivative calculation files to Derivative Cover folder
#
# Deleting contents of the temporary folder ...
#   0%|          | 0/153 [00:00<?, ?it/s]
# 0.1sec deleting contents of the temporary folder completed
#
# 1min 26.3sec total time to compile and save 153 derivative calculation files for 30 Jul 2026
#
#
# ################################################
# #                                              #
# #     END 2/4 derv_checker_compiling.ipynb     #
# #                                              #
# ################################################
#
#
#
#
# ##############################################
# #                                            #
# #  START 3/4 derv_checker_summarising.ipynb  #
# #                                            #
# ##############################################
#
#
# Importing libraries to summarise the derivative calcs ...
#  0.4sec importing libraries to summarise the derivative calcs
#
# Getting the reporting date and names of completed derivative files ...
#  Get scandir() of derivative calcs folder for Thu 30 July 2026
# 3765it [00:00, 297639.37it/s]
#  153 funds
#  0.0sec to get scandir() of derivative calcs folder for Thu 30 July 2026
#  Thursday 30 Jul 2026 for 153 funds: 3BBCIINC, ABMMBND, ADRRC, ADVMB, AFGBAL, AFLBAL, AFLMMF, AMMARF, AMPBQP, ASBTOS, ASHFLX, BCICEF, BCIFIF, BPROV, CCNPF, CMPFCASH, CMPFFLEX, CMPFINC, CSIRBQP, ECICBALC, ELCIPF, ENGENIP, ENGENMBF, FEMPBF, GACASH, GAEMBF, GEMSMEDC, GMRETF, GMRETF2, GRFINV, GTCWP2, HOLADC, HOLDINC, HOLEQU, HOLIDC, HOLMMF, HOLYPF, HOSMED, IJGCOR, IJGIPF, IMPALA, IMPBAL_C, IMPREF_C, IPIPF, ISPFP, LEZAFFI, LEZALDI, LPIIFTAA, MASAINC, MASAINRF, MASAMMF, MASASI, MASASIRF, MEDINC, MGFYQP, MOMBBF, MOMBBRF, MOMFLX, MOMFXB, MOMIPF, MOMPRET, MOMTAAHI, MOMTAALI, MOMTAAMI, MULTICH, MWPFEQU, MWPFILB, MYQIP, NEDMED, NESEQU, NFMWEQU, NFMWAGG, NGKINC, OMMAIF, PABS, PANDA, PBFETF, PBNDQ, PCBF, PCCEF, PCEQTF, PCGEARF, PCGEF, PCSHQ, PEQ, PEQF, PETFIP, PEYF, PFFIF, PGCBF, PGCEF, PGIPFA, PGPCEM_C, PGPCGE_C, PGPGARF, PGPGBF_C, PGPGIF_C, PGPRF_C, PICPROV, PIF, PIMBAL, PIMEVO, PIMIDF, PIPF, PIPFP, PLMED, PLPRNA, PMMF, POIF_C, PORFIP, PPEF, PPOS, PPSBAL_C, PPSFLEX, PPSNAM, PPSRBNQ, PPWEQU, PRPABF, PRPDBF, PSIF, PSILB, PSPAM, PSSPFEQU, PSTIF, PTIF, QIFFGIF, SAAMCAU, SAAMINC, SAAMMOD, SABCCSHF, SDINCPM, SILAIF, SILEQF, SISLP, SMMAIF, SMMIBF, SMMILP, SMMRRF, SNPFEQU, SSLSP, STBFIP, TRFINC, TRFWLTH, UCT3YQ, UCTINC, UCTRFBAL, UCTRFINC, UNISABAL, USAIPF, UWRFCON, UWRFGRO, VMPTAA_C, PWMIPF_P
#
#  A summary sheet is required
#  153 completed derivative calculation files at Thursday 30 July 2026
#
#  3.4sec getting the reporting date and names of completed derivative files
#
# Populating the summary dataframe with 153 funds for Thursday 30 July 2026 ...
# 100%|████████████████████████████████████████████████████████████████████████████| 153/153 [00:35<00:00,  4.33it/s]
#  35.3sec populating the summary dataframe with 153 funds for Thursday 30 July 2026
#
# Sorting and then saving the summary dataframe with 153 funds for Thursday 30 July 2026 ...
#  0.4sec sorting and then saving the summary dataframe with 153 funds for Thursday 30 July 2026
#
# Writing the dataframe to a sheet ...
#   0 "UNKNOWN" securities found and amended:
#   0 "No data" funds:
#
# Summary file:
#  \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Derivative Cover\Derv 30Jul2026.xlsx
#
# 10.0sec writing the dataframe to a sheet
# Prettifying and adding links to the summary sheet with xlwings ...
#   Adding investment team names and links to fund mandates and calculation sheets
#   0%|                                                                                      | 0/153 [00:00<?, ?it/s]C:\Users\hilton.netta\AppData\Local\Temp\ipykernel_19416\928037208.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   shtS['A' + str(index + 2)].add_hyperlink(fr'{pthEXPORTS}\{row[0]} Derv Calc {rptDate.strftime("%d%b%Y")}.xlsx', f'{row[0]}') # link to calc sheet
# C:\Users\hilton.netta\AppData\Local\Temp\ipykernel_19416\928037208.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   shtS['W' + str(index + 2)].add_hyperlink(fr'{pthMandates}\{row[0]} Rules.docx',f'{row[0]}')                            # link to fund mandate
# 100%|████████████████████████████████████████████████████████████████████████████| 153/153 [00:31<00:00,  4.91it/s]
#   31.2sec adding investment team names and links to fund mandates and calculation sheets
#
#    Adding conditional formats for values that are negative or exceed 100% of NAV; 2907 = 153 funds x 19 columns
# 100%|██████████████████████████████████████████████████████████████████████████| 2907/2907 [00:36<00:00, 80.60it/s]
#   36.1sec adding conditional formats for values that are negative or exceed 100% of NAV
#   \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Derivative Cover\Derv 30Jul2026.xlsx
#
# 1min 13.3sec prettifying and adding links to the summary sheet with xlwings
#
# Saving the summary dataframe to the derv_summary.xlsx template; 2926 = (153 funds + 1) x 19 columns
# 100%|██████████████████████████████████████████████████████████████████████████| 2926/2926 [00:44<00:00, 65.99it/s]
#   \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Daily\derv_summary.xlsx
#
#  1min 3.0sec saving the summary dataframe to the derv_summary.xlsx template
#
# Deleting contents of the local temporary folder ...
# 0it [00:00, ?it/s]
# 0.0sec deleting contents of the local temporary folder completed
#
# 3min 5.9sec roundtrip time to summarise derivative calcs
#
#
#
# ##############################################
# #                                            #
# #   END 3/4 derv_checker_summarising.ipynb   #
# #                                            #
# ##############################################
#
#
#
#
# ##############################################
# #                                            #
# #      START 4/4 DERV_CHECKER_FREECOVER      #
# #                                            #
# ##############################################
#
#
# Importing libraries and constants for the free cover report ...
#  0.4sec importing libraries and constants for the free cover report
#
# Getting the reporting date and the comparative prior reporting date ...
#
#  Thu 30 Jul 2026 current report date
#  Wed 29 Jul 2026 prior report date
#  10.0% threshold
#
#  2.5sec getting the reporting date and the comparative prior reporting date
#
# Dataframing current and prior working day derivative summary files ...
#
#   \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Derivative Cover\Derv 29Jul2026.xlsx
#   \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Derivative Cover\Derv 30Jul2026.xlsx
#
#  1.0sec dataframing current and prior working day derivative summary files
#
# Dataframing current and prior day derivative summaries ...
#
#
# 4 cols: ['Derivative Cover Calcs 30Jul2026', 'UT?', '#', 'Cash Cover']
# 2 cols: ['Fund Code', 'Fund Name']
# 6 cols: ['Derivative Cover Calcs 30Jul2026', 'UT?', '#', 'Cash Cover', 'Fund Code', 'Fund Name']
#
#
# 4 cols: ['Derivative Cover Calcs 29Jul2026', 'UT?', '#', 'Cash Cover']
# 10 cols: ['Derivative Cover Calcs 30Jul2026', 'UT?_x', '#_x', 'Cash Cover_x', 'Fund Code', 'Fund Name', 'Derivative Cover Calcs 29Jul2026', 'UT?_y', '#_y', 'Cash Cover_y']
#
#
# 6 cols: ['Derivative Cover Calcs 30Jul2026', 'UT?_x', '#_x', 'Cash Cover_x', 'Fund Name', 'Cash Cover_y']
#  0.0sec dataframing current and prior day derivative summaries
#
# Saving the newest Free Cover.xlsm file ...
#
#  19.2sec saving the newest \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Daily\Free Cover.xlsm
#
# 23.2sec roundtrip time for free cover file
#
#
# ##############################################
# #                                            #
# #       END 4/4 DERV_CHECKER_FREECOVER       #
# #                                            #
# ##############################################
#
#
# 11h43:11s Fri 31 Jul 2026:                 \Derv 29Jul2026.xlsx was completed at Thu Jul 30 09:53:06 2026
#
#
#  5min 9.4sec roundtrip time to download and complete 29 Jul 2026 derivative cover reports
#
#
# ################################################
# #                                              #
# #   START 1/4 derv_checker_downloading.ipynb   #
# #                                              #
# ################################################
#
#
# Importing libraries and setting paths for derv_checker_downloading.ipynb ...
#  6.4sec importing libraries and setting paths for derv_checker_downloading.ipynb
#
# Deriving file names ...
#
# Wednesday 29 Jul 2026 for 153 funds:
#  3BBCIINC,ABMMBND,ADRRC,ADVMB,AFGBAL,AFLBAL,AFLMMF,AMMARF,AMPBQP,ASBTOS,ASHFLX,BCICEF,BCIFIF,BPROV,CCNPF,CMPFCASH,CMPFFLEX,CMPFINC,CSIRBQP,ECICBALC,ELCIPF,ENGENIP,ENGENMBF,FEMPBF,GACASH,GAEMBF,GEMSMEDC,GMRETF,GMRETF2,GRFINV,GTCWP2,HOLADC,HOLDINC,HOLEQU,HOLIDC,HOLMMF,HOLYPF,HOSMED,IJGCOR,IJGIPF,IMPALA,IMPBAL_C,IMPREF_C,IPIPF,ISPFP,LEZAFFI,LEZALDI,LPIIFTAA,MASAINC,MASAINRF,MASAMMF,MASASI,MASASIRF,MEDINC,MGFYQP,MOMBBF,MOMBBRF,MOMFLX,MOMFXB,MOMIPF,MOMPRET,MOMTAAHI,MOMTAALI,MOMTAAMI,MULTICH,MWPFEQU,MWPFILB,MYQIP,NEDMED,NESEQU,NFMWEQU,NFMWAGG,NGKINC,OMMAIF,PABS,PANDA,PBFETF,PBNDQ,PCBF,PCCEF,PCEQTF,PCGEARF,PCGEF,PCSHQ,PEQ,PEQF,PETFIP,PEYF,PFFIF,PGCBF,PGCEF,PGIPFA,PGPCEM_C,PGPCGE_C,PGPGARF,PGPGBF_C,PGPGIF_C,PGPRF_C,PICPROV,PIF,PIMBAL,PIMEVO,PIMIDF,PIPF,PIPFP,PLMED,PLPRNA,PMMF,POIF_C,PORFIP,PPEF,PPOS,PPSBAL_C,PPSFLEX,PPSNAM,PPSRBNQ,PPWEQU,PRPABF,PRPDBF,PSIF,PSILB,PSPAM,PSSPFEQU,PSTIF,PTIF,QIFFGIF,SAAMCAU,SAAMINC,SAAMMOD,SABCCSHF,SDINCPM,SILAIF,SILEQF,SISLP,SMMAIF,SMMIBF,SMMILP,SMMRRF,SNPFEQU,SSLSP,STBFIP,TRFINC,TRFWLTH,UCT3YQ,UCTINC,UCTRFBAL,UCTRFINC,UNISABAL,USAIPF,UWRFCON,UWRFGRO,VMPTAA_C,PWMIPF_P
#
#  A summary sheet is required
#
# 0.0sec deriving file names
#
# Downloading and then saving holdings data ...
#   PARN (153) 29Jul2026.csv already exists
#
#  PARN (153) 29Jul2026.csv
#
#
# 0.0sec downloading and then saving holdings data
#
# Downloading and then saving derivative data ...
#   DERV (153) 29Jul2026.csv already exists
# 0.0sec downloading and then saving derivative data
#
# Getting the reporting date and latest downloaded holdings and derivatives files
#
#  Expected downloads:
#   C:\Users\hilton.netta\Downloads\PARN (153) 29Jul2026.csv which exists
#   C:\Users\hilton.netta\Downloads\DERV (153) 29Jul2026.csv which exists
#  A summary sheet is required
#
# 0.0sec getting the reporting date and latest downloaded holdings and derivatives files
#
# 6.5sec downloading holdings and derivative metrics. Next step is compiling.
#
#
#
# ################################################
# #                                              #
# #    END 1/4 derv_checker_downloading.ipynb    #
# #                                              #
# ################################################
#
#
#
#
# ################################################
# #                                              #
# #    START 2/4 derv_checker_compiling.ipynb    #
# #                                              #
# ################################################
#
#
# Importing libraries and constants ...
#  0.0sec importing libraries and constants
#
# Getting the reporting date and latest downloaded holdings and derivatives files...
#
#  Thursday 30 Jul 2026 for 153 funds:
#  3BBCIINC,ABMMBND,ADRRC,ADVMB,AFGBAL,AFLBAL,AFLMMF,AMMARF,AMPBQP,ASBTOS,ASHFLX,BCICEF,BCIFIF,BPROV,CCNPF,CMPFCASH,CMPFFLEX,CMPFINC,CSIRBQP,ECICBALC,ELCIPF,ENGENIP,ENGENMBF,FEMPBF,GACASH,GAEMBF,GEMSMEDC,GMRETF,GMRETF2,GRFINV,GTCWP2,HOLADC,HOLDINC,HOLEQU,HOLIDC,HOLMMF,HOLYPF,HOSMED,IJGCOR,IJGIPF,IMPALA,IMPBAL_C,IMPREF_C,IPIPF,ISPFP,LEZAFFI,LEZALDI,LPIIFTAA,MASAINC,MASAINRF,MASAMMF,MASASI,MASASIRF,MEDINC,MGFYQP,MOMBBF,MOMBBRF,MOMFLX,MOMFXB,MOMIPF,MOMPRET,MOMTAAHI,MOMTAALI,MOMTAAMI,MULTICH,MWPFEQU,MWPFILB,MYQIP,NEDMED,NESEQU,NFMWEQU,NFMWAGG,NGKINC,OMMAIF,PABS,PANDA,PBFETF,PBNDQ,PCBF,PCCEF,PCEQTF,PCGEARF,PCGEF,PCSHQ,PEQ,PEQF,PETFIP,PEYF,PFFIF,PGCBF,PGCEF,PGIPFA,PGPCEM_C,PGPCGE_C,PGPGARF,PGPGBF_C,PGPGIF_C,PGPRF_C,PICPROV,PIF,PIMBAL,PIMEVO,PIMIDF,PIPF,PIPFP,PLMED,PLPRNA,PMMF,POIF_C,PORFIP,PPEF,PPOS,PPSBAL_C,PPSFLEX,PPSNAM,PPSRBNQ,PPWEQU,PRPABF,PRPDBF,PSIF,PSILB,PSPAM,PSSPFEQU,PSTIF,PTIF,QIFFGIF,SAAMCAU,SAAMINC,SAAMMOD,SABCCSHF,SDINCPM,SILAIF,SILEQF,SISLP,SMMAIF,SMMIBF,SMMILP,SMMRRF,SNPFEQU,SSLSP,STBFIP,TRFINC,TRFWLTH,UCT3YQ,UCTINC,UCTRFBAL,UCTRFINC,UNISABAL,USAIPF,UWRFCON,UWRFGRO,VMPTAA_C,PWMIPF_P
#
#  Expected downloads:
#   C:\Users\hilton.netta\Downloads\PARN (153) 30Jul2026.csv (holdings) which exists
#   C:\Users\hilton.netta\Downloads\DERV (153) 30Jul2026.csv (derivatives) which exists
#  A summary sheet is required
#
#
# 2.6sec getting the reporting date and latest downloaded holdings and derivatives files
#
# Creating holdings and deltas dataframes ...
#   0 "UNKNOWN" securities identified and renamed:
#
# 0.5sec creating holdings and deltas dataframes
#
# Recalculating and saving fund Total Market Value percentages ...
# 0it [00:00, ?it/s]
#   0%|          | 0/8226 [00:00<?, ?it/s]
#  1.4sec recalculating and saving fund Total Market Value percentages
#
#
# Determining the derivative cover reports already completed for Thu 30 Jul 2026 ...
#
# 0 completed:
#
#
# 153 remaining:
#  3BBCIINC,ABMMBND,ADRRC,ADVMB,AFGBAL,AFLBAL,AFLMMF,AMMARF,AMPBQP,ASBTOS,ASHFLX,BCICEF,BCIFIF,BPROV,CCNPF,CMPFCASH,CMPFFLEX,CMPFINC,CSIRBQP,ECICBALC,ELCIPF,ENGENIP,ENGENMBF,FEMPBF,GACASH,GAEMBF,GEMSMEDC,GMRETF,GMRETF2,GRFINV,GTCWP2,HOLADC,HOLDINC,HOLEQU,HOLIDC,HOLMMF,HOLYPF,HOSMED,IJGCOR,IJGIPF,IMPALA,IMPBAL_C,IMPREF_C,IPIPF,ISPFP,LEZAFFI,LEZALDI,LPIIFTAA,MASAINC,MASAINRF,MASAMMF,MASASI,MASASIRF,MEDINC,MGFYQP,MOMBBF,MOMBBRF,MOMFLX,MOMFXB,MOMIPF,MOMPRET,MOMTAAHI,MOMTAALI,MOMTAAMI,MULTICH,MWPFEQU,MWPFILB,MYQIP,NEDMED,NESEQU,NFMWAGG,NFMWEQU,NGKINC,OMMAIF,PABS,PANDA,PBFETF,PBNDQ,PCBF,PCCEF,PCEQTF,PCGEARF,PCGEF,PCSHQ,PEQ,PEQF,PETFIP,PEYF,PFFIF,PGCBF,PGCEF,PGIPFA,PGPCEM_C,PGPCGE_C,PGPGARF,PGPGBF_C,PGPGIF_C,PGPRF_C,PICPROV,PIF,PIMBAL,PIMEVO,PIMIDF,PIPF,PIPFP,PLMED,PLPRNA,PMMF,POIF_C,PORFIP,PPEF,PPOS,PPSBAL_C,PPSFLEX,PPSNAM,PPSRBNQ,PPWEQU,PRPABF,PRPDBF,PSIF,PSILB,PSPAM,PSSPFEQU,PSTIF,PTIF,PWMIPF_P,QIFFGIF,SAAMCAU,SAAMINC,SAAMMOD,SABCCSHF,SDINCPM,SILAIF,SILEQF,SISLP,SMMAIF,SMMIBF,SMMILP,SMMRRF,SNPFEQU,SSLSP,STBFIP,TRFINC,TRFWLTH,UCT3YQ,UCTINC,UCTRFBAL,UCTRFINC,UNISABAL,USAIPF,UWRFCON,UWRFGRO,VMPTAA_C
#
#
# 0.0sec determining the derivative cover reports already completed for Thu 30 Jul 2026: 0 completed, 153 remaining
#
# Compiling derivative calculation files for 153 funds at 30 Jul 2026
#   0%|          | 0/153 [00:00<?, ?it/s]
#  56.8sec compiling derivative calculation files for 153 funds at 30 Jul 2026
#
# Saving the 153 fund derivative calculation files to the Derivative Cover folder ...
#   0%|          | 0/153 [00:00<?, ?it/s]
# 17.9sec saving the 153 fund derivative calculation files to Derivative Cover folder
#
# Deleting contents of the temporary folder ...
#   0%|          | 0/153 [00:00<?, ?it/s]
# 0.2sec deleting contents of the temporary folder completed
#
# 1min 19.6sec total time to compile and save 153 derivative calculation files for 30 Jul 2026
#
#
# ################################################
# #                                              #
# #     END 2/4 derv_checker_compiling.ipynb     #
# #                                              #
# ################################################
#
#
#
#
# ##############################################
# #                                            #
# #  START 3/4 derv_checker_summarising.ipynb  #
# #                                            #
# ##############################################
#
#
# Importing libraries to summarise the derivative calcs ...
#  0.4sec importing libraries to summarise the derivative calcs
#
# Getting the reporting date and names of completed derivative files ...
#  Get scandir() of derivative calcs folder for Thu 30 July 2026
# 3765it [00:00, 315616.47it/s]
#  153 funds
#  0.0sec to get scandir() of derivative calcs folder for Thu 30 July 2026
#  Thursday 30 Jul 2026 for 153 funds: 3BBCIINC, ABMMBND, ADRRC, ADVMB, AFGBAL, AFLBAL, AFLMMF, AMMARF, AMPBQP, ASBTOS, ASHFLX, BCICEF, BCIFIF, BPROV, CCNPF, CMPFCASH, CMPFFLEX, CMPFINC, CSIRBQP, ECICBALC, ELCIPF, ENGENIP, ENGENMBF, FEMPBF, GACASH, GAEMBF, GEMSMEDC, GMRETF, GMRETF2, GRFINV, GTCWP2, HOLADC, HOLDINC, HOLEQU, HOLIDC, HOLMMF, HOLYPF, HOSMED, IJGCOR, IJGIPF, IMPALA, IMPBAL_C, IMPREF_C, IPIPF, ISPFP, LEZAFFI, LEZALDI, LPIIFTAA, MASAINC, MASAINRF, MASAMMF, MASASI, MASASIRF, MEDINC, MGFYQP, MOMBBF, MOMBBRF, MOMFLX, MOMFXB, MOMIPF, MOMPRET, MOMTAAHI, MOMTAALI, MOMTAAMI, MULTICH, MWPFEQU, MWPFILB, MYQIP, NEDMED, NESEQU, NFMWEQU, NFMWAGG, NGKINC, OMMAIF, PABS, PANDA, PBFETF, PBNDQ, PCBF, PCCEF, PCEQTF, PCGEARF, PCGEF, PCSHQ, PEQ, PEQF, PETFIP, PEYF, PFFIF, PGCBF, PGCEF, PGIPFA, PGPCEM_C, PGPCGE_C, PGPGARF, PGPGBF_C, PGPGIF_C, PGPRF_C, PICPROV, PIF, PIMBAL, PIMEVO, PIMIDF, PIPF, PIPFP, PLMED, PLPRNA, PMMF, POIF_C, PORFIP, PPEF, PPOS, PPSBAL_C, PPSFLEX, PPSNAM, PPSRBNQ, PPWEQU, PRPABF, PRPDBF, PSIF, PSILB, PSPAM, PSSPFEQU, PSTIF, PTIF, QIFFGIF, SAAMCAU, SAAMINC, SAAMMOD, SABCCSHF, SDINCPM, SILAIF, SILEQF, SISLP, SMMAIF, SMMIBF, SMMILP, SMMRRF, SNPFEQU, SSLSP, STBFIP, TRFINC, TRFWLTH, UCT3YQ, UCTINC, UCTRFBAL, UCTRFINC, UNISABAL, USAIPF, UWRFCON, UWRFGRO, VMPTAA_C, PWMIPF_P
#
#  A summary sheet is required
#  153 completed derivative calculation files at Thursday 30 July 2026
#
#  5.4sec getting the reporting date and names of completed derivative files
#
# Populating the summary dataframe with 153 funds for Thursday 30 July 2026 ...
# 100%|████████████████████████████████████████████████████████████████████████████| 153/153 [00:40<00:00,  3.80it/s]
#  40.3sec populating the summary dataframe with 153 funds for Thursday 30 July 2026
#
# Sorting and then saving the summary dataframe with 153 funds for Thursday 30 July 2026 ...
#  0.4sec sorting and then saving the summary dataframe with 153 funds for Thursday 30 July 2026
#
# Writing the dataframe to a sheet ...
#   0 "UNKNOWN" securities found and amended:
#   0 "No data" funds:
#
# Summary file:
#  \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Derivative Cover\Derv 30Jul2026.xlsx
#
# 11.5sec writing the dataframe to a sheet
# Prettifying and adding links to the summary sheet with xlwings ...
#   Adding investment team names and links to fund mandates and calculation sheets
#   0%|                                                                                      | 0/153 [00:00<?, ?it/s]C:\Users\hilton.netta\AppData\Local\Temp\ipykernel_19416\928037208.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   shtS['A' + str(index + 2)].add_hyperlink(fr'{pthEXPORTS}\{row[0]} Derv Calc {rptDate.strftime("%d%b%Y")}.xlsx', f'{row[0]}') # link to calc sheet
# C:\Users\hilton.netta\AppData\Local\Temp\ipykernel_19416\928037208.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   shtS['W' + str(index + 2)].add_hyperlink(fr'{pthMandates}\{row[0]} Rules.docx',f'{row[0]}')                            # link to fund mandate
# 100%|████████████████████████████████████████████████████████████████████████████| 153/153 [00:44<00:00,  3.41it/s]
#   44.9sec adding investment team names and links to fund mandates and calculation sheets
#
#    Adding conditional formats for values that are negative or exceed 100% of NAV; 2907 = 153 funds x 19 columns
# 100%|██████████████████████████████████████████████████████████████████████████| 2907/2907 [02:30<00:00, 19.35it/s]
#   2min 30.3sec adding conditional formats for values that are negative or exceed 100% of NAV
#   \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Derivative Cover\Derv 30Jul2026.xlsx
#
# 3min 22.9sec prettifying and adding links to the summary sheet with xlwings
#
# Saving the summary dataframe to the derv_summary.xlsx template; 2926 = (153 funds + 1) x 19 columns
#  33%|████████████████████████▌                                                  | 956/2926 [01:00<02:05, 15.69it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\xlwings\_xlwindows.py:199, in COMRetryObjectWrapper.__getattr__(self, item)
#     198 try:
# --> 199     v = getattr(self._inner, item)
#     200     if isinstance(v, (CDispatch, CoClassBaseClass, DispatchBaseClass)):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\win32com\client\dynamic.py:639, in CDispatch.__getattr__(self, attr)
#     638 # no where else to look.
# --> 639 raise AttributeError("%s.%s" % (self._username_, attr))
#
# AttributeError: __call__.Count
#
# During handling of the above exception, another exception occurred:
#
# com_error                                 Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_19416\1544492260.py:17
#      16 for a_cell in tqdm(shtS_S["D1:V1"].expand("down")):
# ---> 17     if type(a_cell.value) in [float, int]:   # ensure the cell bveing formatted is a float or an integer
#      18         if abs(a_cell.value) >= 100:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\xlwings\main.py:2478, in Range.value(self)
#    2468 """
#    2469 Gets and sets the values for the given Range. See :meth:`xlwings.Range.options`
#    2470 about how to set options, e.g., to transform it into a DataFrame or how to set
#    (...)
#    2476          see :meth:`xlwings.Range.options`
#    2477 """
# -> 2478 return conversion.read(self, None, self._options)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\xlwings\conversion\__init__.py:76, in read(rng, value, options, engine_name)
#      75 pipeline = accessors.get(convert, convert).reader(options)
# ---> 76 ctx = ConversionContext(rng=rng, value=value, engine_name=engine_name)
#      77 pipeline(ctx)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\xlwings\conversion\framework.py:13, in ConversionContext.__init__(self, rng, value, engine_name)
#      11 else:
#      12     # rng can only be None if used via COM server UDFs
# ---> 13     self.engine = rng.sheet.book.app.engine if rng else xlwings.engines["excel"]
#      14 self.value = value
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\xlwings\main.py:1993, in Range.__len__(self)
#    1992 def __len__(self):
# -> 1993     return len(self.impl)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\xlwings\_xlwindows.py:1185, in Range.__len__(self)
#    1184 def __len__(self):
# -> 1185     return (self.xl and self.xl.Count) or 0
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\xlwings\_xlwindows.py:221, in COMRetryObjectWrapper.__getattr__(self, item)
#     220 try:
# --> 221     self._oleobj_.GetIDsOfNames(0, item)
#     222 except pythoncom.ole_error as e:
#
# com_error: (-2147023174, 'The RPC server is unavailable.', None, None)
#
# During handling of the above exception, another exception occurred:
#
# com_error                                 Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_19416\1544492260.py:8
#       6 # open the derv_summary.xlsx derv template and assign values to the holdings and deltas sheets
#       7 import xlwings as xw
# ----> 8 with xw.App(visible=False) as app:
#       9     # populate the summary sheet with derivative cover calc values for each fund
#      10     wb     = xw.Book(os.path.join(pthDaily, 'derv_summary.xlsx')) # open the derv calc workbook as an object
#      11     shtS_S = wb.sheets['Summary']                                # assign sheet containing the funds derivative cover summary
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\xlwings\main.py:793, in App.__exit__(self, exc_type, exc_value, exc_tb)
#     792 def __exit__(self, exc_type, exc_value, exc_tb):
# --> 793     self.quit()
#     794     if sys.platform.startswith("win"):
#     795         try:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\xlwings\main.py:406, in App.quit(self)
#     399 def quit(self):
#     400     """
#     401     Quits the application without saving any workbooks.
#     402
#     403     .. versionadded:: 0.3.3
#     404
#     405     """
# --> 406     return self.impl.quit()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\xlwings\_xlwindows.py:620, in App.quit(self)
#     619 def quit(self):
# --> 620     self.xl.DisplayAlerts = False
#     621     self.xl.Quit()
#     622     self.xl = None
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\xlwings\_xlwindows.py:161, in COMRetryObjectWrapper.__setattr__(self, key, value)
#     159 while True:
#     160     try:
# --> 161         return setattr(self._inner, key, value)
#     162     except pywintypes.com_error as e:
#     163         hresult, msg, exc, arg = e.args
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\win32com\client\__init__.py:595, in DispatchBaseClass.__setattr__(self, attr, value)
#     591 except KeyError:
#     592     raise AttributeError(
#     593         "'%s' object has no attribute '%s'" % (repr(self), attr)
#     594     )
# --> 595 self._oleobj_.Invoke(*(args + (value,) + defArgs))
#
# com_error: (-2147023174, 'The RPC server is unavailable.', None, None)
# (-2147023174, 'The RPC server is unavailable.', None, None)
#
#  7min 42.8sec roundtrip time to download and complete 29 Jul 2026 derivative cover reports
#
#
# ################################################
# ...
# 100%|████████████████████████████████████████████████████████████████████████████| 153/153 [00:09<00:00, 16.96it/s]
#   9.1sec adding investment team names and links to fund mandates and calculation sheets
#
#    Adding conditional formats for values that are negative or exceed 100% of NAV; 2907 = 153 funds x 19 columns
# 100%|██████████████████████████████████████████████████████████████████████████| 2907/2907 [01:42<00:00, 28.25it/s]
#   1min 43.0sec adding conditional formats for values that are negative or exceed 100% of NAV
#   \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Derivative Cover\Derv 30Jul2026.xlsx
#
# 1min 59.0sec prettifying and adding links to the summary sheet with xlwings
#
# Saving the summary dataframe to the derv_summary.xlsx template; 2926 = (153 funds + 1) x 19 columns
# 100%|██████████████████████████████████████████████████████████████████████████| 2926/2926 [01:28<00:00, 33.14it/s]
#   \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Daily\derv_summary.xlsx
#
#  2min 19.2sec saving the summary dataframe to the derv_summary.xlsx template
#
# Deleting contents of the local temporary folder ...
# 0it [00:00, ?it/s]
# 0.0sec deleting contents of the local temporary folder completed
#
# 5min 21.2sec roundtrip time to summarise derivative calcs
#
#
#
# ##############################################
# #                                            #
# #   END 3/4 derv_checker_summarising.ipynb   #
# #                                            #
# ##############################################
#
#
#
#
# ##############################################
# #                                            #
# #      START 4/4 DERV_CHECKER_FREECOVER      #
# #                                            #
# ##############################################
#
#
# Importing libraries and constants for the free cover report ...
#  0.5sec importing libraries and constants for the free cover report
#
# Getting the reporting date and the comparative prior reporting date ...
#
#  Thu 30 Jul 2026 current report date
#  Wed 29 Jul 2026 prior report date
#  10.0% threshold
#
#  2.3sec getting the reporting date and the comparative prior reporting date
#
# Dataframing current and prior working day derivative summary files ...
#
#   \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Derivative Cover\Derv 29Jul2026.xlsx
#   \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Derivative Cover\Derv 30Jul2026.xlsx
#
#  1.2sec dataframing current and prior working day derivative summary files
#
# Dataframing current and prior day derivative summaries ...
#
#
# 4 cols: ['Derivative Cover Calcs 30Jul2026', 'UT?', '#', 'Cash Cover']
# 2 cols: ['Fund Code', 'Fund Name']
# 6 cols: ['Derivative Cover Calcs 30Jul2026', 'UT?', '#', 'Cash Cover', 'Fund Code', 'Fund Name']
#
#
# 4 cols: ['Derivative Cover Calcs 29Jul2026', 'UT?', '#', 'Cash Cover']
# 10 cols: ['Derivative Cover Calcs 30Jul2026', 'UT?_x', '#_x', 'Cash Cover_x', 'Fund Code', 'Fund Name', 'Derivative Cover Calcs 29Jul2026', 'UT?_y', '#_y', 'Cash Cover_y']
#
#
# 6 cols: ['Derivative Cover Calcs 30Jul2026', 'UT?_x', '#_x', 'Cash Cover_x', 'Fund Name', 'Cash Cover_y']
#  0.0sec dataframing current and prior day derivative summaries
#
# Saving the newest Free Cover.xlsm file ...
#
#  19.2sec saving the newest \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Daily\Free Cover.xlsm
#
# 23.3sec roundtrip time for free cover file
#
#
# ##############################################
# #                                            #
# #       END 4/4 DERV_CHECKER_FREECOVER       #
# #                                            #
# ##############################################
#
#
# 12h45:32s Fri 31 Jul 2026:                 \Derv 29Jul2026.xlsx was completed at Thu Jul 30 09:53:06 2026
#
#
#  7min 28.3sec roundtrip time to download and complete 29 Jul 2026 derivative cover reports
#
#
# ################################################
# #                                              #
# #   START 1/4 derv_checker_downloading.ipynb   #
# #                                              #
# ################################################
#
#
# Importing libraries and setting paths for derv_checker_downloading.ipynb ...
#  5.2sec importing libraries and setting paths for derv_checker_downloading.ipynb
#
# Deriving file names ...
#
# Wednesday 29 Jul 2026 for 153 funds:
#  3BBCIINC,ABMMBND,ADRRC,ADVMB,AFGBAL,AFLBAL,AFLMMF,AMMARF,AMPBQP,ASBTOS,ASHFLX,BCICEF,BCIFIF,BPROV,CCNPF,CMPFCASH,CMPFFLEX,CMPFINC,CSIRBQP,ECICBALC,ELCIPF,ENGENIP,ENGENMBF,FEMPBF,GACASH,GAEMBF,GEMSMEDC,GMRETF,GMRETF2,GRFINV,GTCWP2,HOLADC,HOLDINC,HOLEQU,HOLIDC,HOLMMF,HOLYPF,HOSMED,IJGCOR,IJGIPF,IMPALA,IMPBAL_C,IMPREF_C,IPIPF,ISPFP,LEZAFFI,LEZALDI,LPIIFTAA,MASAINC,MASAINRF,MASAMMF,MASASI,MASASIRF,MEDINC,MGFYQP,MOMBBF,MOMBBRF,MOMFLX,MOMFXB,MOMIPF,MOMPRET,MOMTAAHI,MOMTAALI,MOMTAAMI,MULTICH,MWPFEQU,MWPFILB,MYQIP,NEDMED,NESEQU,NFMWEQU,NFMWAGG,NGKINC,OMMAIF,PABS,PANDA,PBFETF,PBNDQ,PCBF,PCCEF,PCEQTF,PCGEARF,PCGEF,PCSHQ,PEQ,PEQF,PETFIP,PEYF,PFFIF,PGCBF,PGCEF,PGIPFA,PGPCEM_C,PGPCGE_C,PGPGARF,PGPGBF_C,PGPGIF_C,PGPRF_C,PICPROV,PIF,PIMBAL,PIMEVO,PIMIDF,PIPF,PIPFP,PLMED,PLPRNA,PMMF,POIF_C,PORFIP,PPEF,PPOS,PPSBAL_C,PPSFLEX,PPSNAM,PPSRBNQ,PPWEQU,PRPABF,PRPDBF,PSIF,PSILB,PSPAM,PSSPFEQU,PSTIF,PTIF,QIFFGIF,SAAMCAU,SAAMINC,SAAMMOD,SABCCSHF,SDINCPM,SILAIF,SILEQF,SISLP,SMMAIF,SMMIBF,SMMILP,SMMRRF,SNPFEQU,SSLSP,STBFIP,TRFINC,TRFWLTH,UCT3YQ,UCTINC,UCTRFBAL,UCTRFINC,UNISABAL,USAIPF,UWRFCON,UWRFGRO,VMPTAA_C,PWMIPF_P
#
#  A summary sheet is required
#
# 0.0sec deriving file names
#
# Downloading and then saving holdings data ...
#   PARN (153) 29Jul2026.csv already exists
#
#  PARN (153) 29Jul2026.csv
#
#
# 0.0sec downloading and then saving holdings data
#
# Downloading and then saving derivative data ...
#   DERV (153) 29Jul2026.csv already exists
# 0.0sec downloading and then saving derivative data
#
# Getting the reporting date and latest downloaded holdings and derivatives files
#
#  Expected downloads:
#   C:\Users\hilton.netta\Downloads\PARN (153) 29Jul2026.csv which exists
#   C:\Users\hilton.netta\Downloads\DERV (153) 29Jul2026.csv which exists
#  A summary sheet is required
#
# 0.0sec getting the reporting date and latest downloaded holdings and derivatives files
#
# 5.3sec downloading holdings and derivative metrics. Next step is compiling.
#
#
#
# ################################################
# #                                              #
# #    END 1/4 derv_checker_downloading.ipynb    #
# #                                              #
# ################################################
#
#
#
#
# ################################################
# #                                              #
# #    START 2/4 derv_checker_compiling.ipynb    #
# #                                              #
# ################################################
#
#
# Importing libraries and constants ...
#  0.0sec importing libraries and constants
#
# Getting the reporting date and latest downloaded holdings and derivatives files...
#
#  Thursday 30 Jul 2026 for 153 funds:
#  3BBCIINC,ABMMBND,ADRRC,ADVMB,AFGBAL,AFLBAL,AFLMMF,AMMARF,AMPBQP,ASBTOS,ASHFLX,BCICEF,BCIFIF,BPROV,CCNPF,CMPFCASH,CMPFFLEX,CMPFINC,CSIRBQP,ECICBALC,ELCIPF,ENGENIP,ENGENMBF,FEMPBF,GACASH,GAEMBF,GEMSMEDC,GMRETF,GMRETF2,GRFINV,GTCWP2,HOLADC,HOLDINC,HOLEQU,HOLIDC,HOLMMF,HOLYPF,HOSMED,IJGCOR,IJGIPF,IMPALA,IMPBAL_C,IMPREF_C,IPIPF,ISPFP,LEZAFFI,LEZALDI,LPIIFTAA,MASAINC,MASAINRF,MASAMMF,MASASI,MASASIRF,MEDINC,MGFYQP,MOMBBF,MOMBBRF,MOMFLX,MOMFXB,MOMIPF,MOMPRET,MOMTAAHI,MOMTAALI,MOMTAAMI,MULTICH,MWPFEQU,MWPFILB,MYQIP,NEDMED,NESEQU,NFMWEQU,NFMWAGG,NGKINC,OMMAIF,PABS,PANDA,PBFETF,PBNDQ,PCBF,PCCEF,PCEQTF,PCGEARF,PCGEF,PCSHQ,PEQ,PEQF,PETFIP,PEYF,PFFIF,PGCBF,PGCEF,PGIPFA,PGPCEM_C,PGPCGE_C,PGPGARF,PGPGBF_C,PGPGIF_C,PGPRF_C,PICPROV,PIF,PIMBAL,PIMEVO,PIMIDF,PIPF,PIPFP,PLMED,PLPRNA,PMMF,POIF_C,PORFIP,PPEF,PPOS,PPSBAL_C,PPSFLEX,PPSNAM,PPSRBNQ,PPWEQU,PRPABF,PRPDBF,PSIF,PSILB,PSPAM,PSSPFEQU,PSTIF,PTIF,QIFFGIF,SAAMCAU,SAAMINC,SAAMMOD,SABCCSHF,SDINCPM,SILAIF,SILEQF,SISLP,SMMAIF,SMMIBF,SMMILP,SMMRRF,SNPFEQU,SSLSP,STBFIP,TRFINC,TRFWLTH,UCT3YQ,UCTINC,UCTRFBAL,UCTRFINC,UNISABAL,USAIPF,UWRFCON,UWRFGRO,VMPTAA_C,PWMIPF_P
#
#  Expected downloads:
#   C:\Users\hilton.netta\Downloads\PARN (153) 30Jul2026.csv (holdings) which exists
#   C:\Users\hilton.netta\Downloads\DERV (153) 30Jul2026.csv (derivatives) which exists
#  A summary sheet is required
#
#
# 4.5sec getting the reporting date and latest downloaded holdings and derivatives files
#
# Creating holdings and deltas dataframes ...
#   0 "UNKNOWN" securities identified and renamed:
#
# 0.8sec creating holdings and deltas dataframes
#
# Recalculating and saving fund Total Market Value percentages ...
# 0it [00:00, ?it/s]
#   0%|          | 0/8226 [00:00<?, ?it/s]
#  3.3sec recalculating and saving fund Total Market Value percentages
#
#
# Determining the derivative cover reports already completed for Thu 30 Jul 2026 ...
#
# 0 completed:
#
#
# 153 remaining:
#  3BBCIINC,ABMMBND,ADRRC,ADVMB,AFGBAL,AFLBAL,AFLMMF,AMMARF,AMPBQP,ASBTOS,ASHFLX,BCICEF,BCIFIF,BPROV,CCNPF,CMPFCASH,CMPFFLEX,CMPFINC,CSIRBQP,ECICBALC,ELCIPF,ENGENIP,ENGENMBF,FEMPBF,GACASH,GAEMBF,GEMSMEDC,GMRETF,GMRETF2,GRFINV,GTCWP2,HOLADC,HOLDINC,HOLEQU,HOLIDC,HOLMMF,HOLYPF,HOSMED,IJGCOR,IJGIPF,IMPALA,IMPBAL_C,IMPREF_C,IPIPF,ISPFP,LEZAFFI,LEZALDI,LPIIFTAA,MASAINC,MASAINRF,MASAMMF,MASASI,MASASIRF,MEDINC,MGFYQP,MOMBBF,MOMBBRF,MOMFLX,MOMFXB,MOMIPF,MOMPRET,MOMTAAHI,MOMTAALI,MOMTAAMI,MULTICH,MWPFEQU,MWPFILB,MYQIP,NEDMED,NESEQU,NFMWAGG,NFMWEQU,NGKINC,OMMAIF,PABS,PANDA,PBFETF,PBNDQ,PCBF,PCCEF,PCEQTF,PCGEARF,PCGEF,PCSHQ,PEQ,PEQF,PETFIP,PEYF,PFFIF,PGCBF,PGCEF,PGIPFA,PGPCEM_C,PGPCGE_C,PGPGARF,PGPGBF_C,PGPGIF_C,PGPRF_C,PICPROV,PIF,PIMBAL,PIMEVO,PIMIDF,PIPF,PIPFP,PLMED,PLPRNA,PMMF,POIF_C,PORFIP,PPEF,PPOS,PPSBAL_C,PPSFLEX,PPSNAM,PPSRBNQ,PPWEQU,PRPABF,PRPDBF,PSIF,PSILB,PSPAM,PSSPFEQU,PSTIF,PTIF,PWMIPF_P,QIFFGIF,SAAMCAU,SAAMINC,SAAMMOD,SABCCSHF,SDINCPM,SILAIF,SILEQF,SISLP,SMMAIF,SMMIBF,SMMILP,SMMRRF,SNPFEQU,SSLSP,STBFIP,TRFINC,TRFWLTH,UCT3YQ,UCTINC,UCTRFBAL,UCTRFINC,UNISABAL,USAIPF,UWRFCON,UWRFGRO,VMPTAA_C
#
#
# 0.0sec determining the derivative cover reports already completed for Thu 30 Jul 2026: 0 completed, 153 remaining
#
# Compiling derivative calculation files for 153 funds at 30 Jul 2026
#   0%|          | 0/153 [00:00<?, ?it/s]
#  1min 36.8sec compiling derivative calculation files for 153 funds at 30 Jul 2026
#
# Saving the 153 fund derivative calculation files to the Derivative Cover folder ...
#   0%|          | 0/153 [00:00<?, ?it/s]
# 26.1sec saving the 153 fund derivative calculation files to Derivative Cover folder
#
# Deleting contents of the temporary folder ...
#   0%|          | 0/153 [00:00<?, ?it/s]
# 0.5sec deleting contents of the temporary folder completed
#
# 2min 12.1sec total time to compile and save 153 derivative calculation files for 30 Jul 2026
#
#
# ################################################
# #                                              #
# #     END 2/4 derv_checker_compiling.ipynb     #
# #                                              #
# ################################################
#
#
#
#
# ##############################################
# #                                            #
# #  START 3/4 derv_checker_summarising.ipynb  #
# #                                            #
# ##############################################
#
#
# Importing libraries to summarise the derivative calcs ...
#  0.4sec importing libraries to summarise the derivative calcs
#
# Getting the reporting date and names of completed derivative files ...
#  Get scandir() of derivative calcs folder for Thu 30 July 2026
# 3765it [00:00, 243512.69it/s]
#  153 funds
#  0.0sec to get scandir() of derivative calcs folder for Thu 30 July 2026
#  Thursday 30 Jul 2026 for 153 funds: 3BBCIINC, ABMMBND, ADRRC, ADVMB, AFGBAL, AFLBAL, AFLMMF, AMMARF, AMPBQP, ASBTOS, ASHFLX, BCICEF, BCIFIF, BPROV, CCNPF, CMPFCASH, CMPFFLEX, CMPFINC, CSIRBQP, ECICBALC, ELCIPF, ENGENIP, ENGENMBF, FEMPBF, GACASH, GAEMBF, GEMSMEDC, GMRETF, GMRETF2, GRFINV, GTCWP2, HOLADC, HOLDINC, HOLEQU, HOLIDC, HOLMMF, HOLYPF, HOSMED, IJGCOR, IJGIPF, IMPALA, IMPBAL_C, IMPREF_C, IPIPF, ISPFP, LEZAFFI, LEZALDI, LPIIFTAA, MASAINC, MASAINRF, MASAMMF, MASASI, MASASIRF, MEDINC, MGFYQP, MOMBBF, MOMBBRF, MOMFLX, MOMFXB, MOMIPF, MOMPRET, MOMTAAHI, MOMTAALI, MOMTAAMI, MULTICH, MWPFEQU, MWPFILB, MYQIP, NEDMED, NESEQU, NFMWEQU, NFMWAGG, NGKINC, OMMAIF, PABS, PANDA, PBFETF, PBNDQ, PCBF, PCCEF, PCEQTF, PCGEARF, PCGEF, PCSHQ, PEQ, PEQF, PETFIP, PEYF, PFFIF, PGCBF, PGCEF, PGIPFA, PGPCEM_C, PGPCGE_C, PGPGARF, PGPGBF_C, PGPGIF_C, PGPRF_C, PICPROV, PIF, PIMBAL, PIMEVO, PIMIDF, PIPF, PIPFP, PLMED, PLPRNA, PMMF, POIF_C, PORFIP, PPEF, PPOS, PPSBAL_C, PPSFLEX, PPSNAM, PPSRBNQ, PPWEQU, PRPABF, PRPDBF, PSIF, PSILB, PSPAM, PSSPFEQU, PSTIF, PTIF, QIFFGIF, SAAMCAU, SAAMINC, SAAMMOD, SABCCSHF, SDINCPM, SILAIF, SILEQF, SISLP, SMMAIF, SMMIBF, SMMILP, SMMRRF, SNPFEQU, SSLSP, STBFIP, TRFINC, TRFWLTH, UCT3YQ, UCTINC, UCTRFBAL, UCTRFINC, UNISABAL, USAIPF, UWRFCON, UWRFGRO, VMPTAA_C, PWMIPF_P
#
#  A summary sheet is required
#  153 completed derivative calculation files at Thursday 30 July 2026
#
#  3.3sec getting the reporting date and names of completed derivative files
#
# Populating the summary dataframe with 153 funds for Thursday 30 July 2026 ...
# 100%|████████████████████████████████████████████████████████████████████████████| 153/153 [00:52<00:00,  2.94it/s]
#  52.1sec populating the summary dataframe with 153 funds for Thursday 30 July 2026
#
# Sorting and then saving the summary dataframe with 153 funds for Thursday 30 July 2026 ...
#  1.2sec sorting and then saving the summary dataframe with 153 funds for Thursday 30 July 2026
#
# Writing the dataframe to a sheet ...
#   0 "UNKNOWN" securities found and amended:
#   0 "No data" funds:
#
# Summary file:
#  \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Derivative Cover\Derv 30Jul2026.xlsx
#
# 19.4sec writing the dataframe to a sheet
# Prettifying and adding links to the summary sheet with xlwings ...
#   Adding investment team names and links to fund mandates and calculation sheets
#   0%|                                                                                      | 0/153 [00:00<?, ?it/s]C:\Users\hilton.netta\AppData\Local\Temp\ipykernel_19416\928037208.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   shtS['A' + str(index + 2)].add_hyperlink(fr'{pthEXPORTS}\{row[0]} Derv Calc {rptDate.strftime("%d%b%Y")}.xlsx', f'{row[0]}') # link to calc sheet
# C:\Users\hilton.netta\AppData\Local\Temp\ipykernel_19416\928037208.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   shtS['W' + str(index + 2)].add_hyperlink(fr'{pthMandates}\{row[0]} Rules.docx',f'{row[0]}')                            # link to fund mandate
# 100%|████████████████████████████████████████████████████████████████████████████| 153/153 [00:07<00:00, 20.48it/s]
#   7.5sec adding investment team names and links to fund mandates and calculation sheets
#
#    Adding conditional formats for values that are negative or exceed 100% of NAV; 2907 = 153 funds x 19 columns
# 100%|██████████████████████████████████████████████████████████████████████████| 2907/2907 [01:46<00:00, 27.31it/s]
#   1min 46.5sec adding conditional formats for values that are negative or exceed 100% of NAV
#   \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Derivative Cover\Derv 30Jul2026.xlsx
#
# 2min 4.5sec prettifying and adding links to the summary sheet with xlwings
#
# Saving the summary dataframe to the derv_summary.xlsx template; 2926 = (153 funds + 1) x 19 columns
#  26%|███████████████████▋                                                       | 766/2926 [00:49<02:44, 13.12it/s]
