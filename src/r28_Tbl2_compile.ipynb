# %% [markdown]
# # Reg 28 Table 2 (Infrastructure)

# %% [markdown]
# ### Dependencies:
# ### C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/r28_Tbl2.ipynb

# %%
#https://stackoverflow.com/questions/72962306/how-to-use-run-command-to-execute-another-notebook-using-file-path
# %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/r28_Tbl2.ipynb"
# Out:
# Importing libraries ...
# Importing libraries completed: 1.2sec
#
# Setting up paths ...
# Setting up paths completed: 0.0sec
#
# Making utility functions ...
# Making utility functions completed: 0.0sec
#
# Getting report variables ...
#   ECICBALC 29Feb2024 Reg28
# Getting report variables completed: 0.7sec
#
# Getting Table 2 items ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_4592\1710173499.py:5
#       2 start_time = time.time()
#       3 print(f'Getting Table 2 items ...')
# ----> 5 shtr          = pd.read_excel(os.path.join(pth_rpt, f'{fnd} {rpt_Type} {rptDate.strftime("%d%b%Y")}.xlsx'), \
#       6                         index_col = None,  header = 0, usecols = 'A:K').dropna(subset = ['Entity Name']) # reg categorised sheet
# ...

# %%
# Python reports   P:\Investment Operations\GRC\Compliance\Daily\py_reports.xlsm
# Reporting folder P:\Investment Operations\GRC\Compliance\Reg28 and Reg30 Reporting
# Table 2 template P:\Working Folders\Hilton\W\!Reg28_Tbl2.xlsx
# Test folder      P:\Working Folders\Hilton\W\Reg_Tests
