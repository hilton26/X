# %% [markdown]
# # Reg 28 Table 2 (Infrastructure)

# %% [markdown]
# ### Dependencies:
# ### C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/r28_Tbl2_bulk.ipynb

# %%
#https://stackoverflow.com/questions/72962306/how-to-use-run-command-to-execute-another-notebook-using-file-path
# %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/r28_Tbl2_bulk.ipynb"
# Out:
# ##############################################
# #            START r28_Tbl2_bulk             #
# ##############################################
# Importing libraries ...
# 1.6sec importing libraries completed
#
# Setting up paths ...
# 0.0sec setting up paths completed
#
# Getting report variables ...
# 138 Reg28 files for 30Jun2025 in the reporting folder
#
# Funds without corresponding long names (0):
#
# Funds without a completed Reg28 file (0):
#
#  Report date: 30Jun2025 Reg28
#  Fund (1, i.e., 1 in reporting list less 0 unnamed less 0 without Reg 28 sheets): AFPFLB
#
# 11.6sec getting report variables completed
#
# Looping over 1 fund ...
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:01<00:00,  1.23s/it]
# 1 Reg 28 Table 2 reports for 30Jun2025 completed and stored here P:\Working Folders\Hilton\W\Reg_Tests
# ##############################################
# #              END r28_Tbl2_bulk             #
# ...

# %%
# Python reports   P:\Investment Operations\GRC\Compliance\Daily\py_reports.xlsm
# Reporting folder P:\Investment Operations\GRC\Compliance\Reg28 and Reg30 Reporting
# Table 2 template P:\Working Folders\Hilton\W\!Reg28_Tbl2.xlsx
# Test folder      P:\Working Folders\Hilton\W\Reg_Tests
