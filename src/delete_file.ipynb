# %% [markdown]
# ### Deletes a file given the path to that file

# %%
#!/usr/bin/env python
# coding: utf-8

# ### Deletes a file given its path

import os, shutil
import pandas as pd
from constants import pthPy, pthHdg, frcv_file, pthDaily

df = pd.read_excel(pthPy, sheet_name="arc", usecols="AW", nrows=9)

# discover the file to be deleted
if pd.isna(df.iloc[2, 0]):
    if df.iloc[0, 0] == "Derv":
        target = frcv_file
    else:
        target = (
            pthHdg
            + "\\"
            + df.iloc[1, 0].strftime("%Y%m%d")
            + " PGF Share Class Hedges.xlsx"
        )
else:
    target = df.iloc[2, 0]

print(f"{target} to be deleted")
# Out:
# \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\PGF UCITS Share Class Hedges\20250919 PGF Share Class Hedges.xlsx to be deleted

# %%
# delete the file
try:
    os.remove(target)
    print(f"File '{target}' deleted successfully.")
except FileNotFoundError:
    print(f"File '{target}' not found.")
except Exception as e:
    print(f"An error occurred: {e}")

# if the Free Cover file was deleted ...
if df.iloc[0, 0] == "Derv":
    source = pthDaily + r"\Free Cover_SPARE.xlsm"
    destination = pthDaily + r"\Free Cover.xlsm"
    shutil.copyfile(source, destination)
# Out:
# \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Daily\Free Cover.xlsm
# File '\\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Daily\Free Cover.xlsm' deleted successfully.

# %%
# !jupyter nbconvert --to script delete_file.ipynb # convert from .ipynb to .py
# Out:
# [NbConvertApp] WARNING | pattern '#' matched no files
# [NbConvertApp] WARNING | pattern 'convert' matched no files
# [NbConvertApp] WARNING | pattern 'from' matched no files
# [NbConvertApp] WARNING | pattern '.ipynb' matched no files
# [NbConvertApp] WARNING | pattern 'to' matched no files
# [NbConvertApp] WARNING | pattern '.py' matched no files
# [NbConvertApp] Converting notebook delete_file.ipynb to script
# [NbConvertApp] Writing 741 bytes to delete_file.py
