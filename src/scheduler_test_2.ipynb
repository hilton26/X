# %% [markdown]
# # Scheduler test

# %% [markdown]
# # Scheduler
# ### gemini Friday 6 June 2025

# %%
# import datetime, time
import schedule
# %run utilities.py

# %%
def my_script():
    """
    This is the function that will be executed.
    Replace this with the logic of your script.
    """
    print("inside my_script()")
    
    print("Running your script...", datetime.now())

# %%
def schedule_script(start_time, end_time):
    """Schedules the script to run every two hours between given times."""
    current_time = datetime.now()
    if start_time <= current_time <= end_time:
        schedule.every(7).seconds.do(my_script)

    while True:
        schedule.run_pending()
        time.sleep(1)

# %%
if __name__ == "__main__":
    current_datetime = datetime.now()
    start_time = current_datetime.replace(hour=8, minute=0)  # Set the start time (e.g., 9:00 AM)
    end_time   = current_datetime.replace(hour=20, minute=30, second=0, microsecond=0)  # Set the end time (e.g., 5:00 PM)
    schedule_script(start_time, end_time)
# Out:
# inside my_script()
# Running your script... 2025-06-06 20:12:15.114949
# inside my_script()
# Running your script... 2025-06-06 20:12:22.118965
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 5
#       3 start_time = current_datetime.replace(hour=8, minute=0)  # Set the start time (e.g., 9:00 AM)
#       4 end_time   = current_datetime.replace(hour=20, minute=30, second=0, microsecond=0)  # Set the end time (e.g., 5:00 PM)
# ----> 5 schedule_script(start_time, end_time)
#
# Cell In[3], line 9, in schedule_script(start_time, end_time)
#       7 while True:
#       8     schedule.run_pending()
# ----> 9     time.sleep(1)
#
# KeyboardInterrupt:

# %%
# TEST

# gemini Friday 6 June 2025

# Get current date and time
current_datetime = datetime.now()

# Specify a date (year, month, day)
specific_date = datetime(2025, 12, 25)

# Set a specific time (hour, minute, second, microsecond)
new_time = current_datetime.replace(hour=10, minute=30, second=0, microsecond=0)

# Set a time for a specific date
specific_time = specific_date.replace(hour=14, minute=45)

print('results:', '\n', f'current_datetime: {current_datetime}', '\n', f'specific_date:    {specific_date}', '\n', \
      f'new_time:         {new_time}', '\n', f'specific_time:    {specific_time}')
