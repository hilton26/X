# %%
# import libraries
import pandas as pd
import schedule
import os, re
from datetime import datetime
import time
from time_diff_function import timediff

# %%
# set up paths to requisite files
pthFIModels = r'P:\Investments\Bonds\Fixed Interest Model Portfolios\Bond funds month end credit info\Template'
file        = r'\All Models Live 2.0.xlsx.xlsm' # '.xlsm' got append to file name around 5 June 2024
pthBM       = r'\\pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\benchmark\Benchmark Detail.csv'

# %%
# get bemchmarks from model
models_albi = pd.read_excel(pthFIModels + file, sheet_name = 'ALBI', engine = 'openpyxl')
models_cili = pd.read_excel(pthFIModels + file, sheet_name = 'CILI', engine = 'openpyxl')
models_igov = pd.read_excel(pthFIModels + file, sheet_name = 'IGOV', engine = 'openpyxl')
albi        = models_albi.iat[31, 16]
cili        = models_cili.iat[26, 16]
igov        = models_igov.iat[18, 16]
print(albi, cili, igov)
# Out:
# 5.467785552445145 9.763381173591807 10.040376636145039
# C:\Users\hilton.netta\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# C:\Users\hilton.netta\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Conditional Formatting extension is not supported and will be removed
#   for idx, row in parser.parse():
# C:\Users\hilton.netta\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# C:\Users\hilton.netta\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Conditional Formatting extension is not supported and will be removed
#   for idx, row in parser.parse():
# ...

# %%
bm = pd.read_csv(pthBM, encoding = 'ISO-8859-1')
# https://stackoverflow.com/questions/18171739/unicodedecodeerror-when-reading-csv-file-in-pandas

# %%
# update benchmarks
bm.at[0, 'ModifiedDuration'] = albi
bm.at[1, 'ModifiedDuration'] = cili
bm.at[2, 'ModifiedDuration'] = igov
bm.at[3, 'ModifiedDuration'] = igov
bm.at[4, 'ModifiedDuration'] = igov
bm.at[5, 'ModifiedDuration'] = albi
bm.at[6, 'ModifiedDuration'] = albi/2 + igov/2
bm.at[7, 'ModifiedDuration'] = .25

# %%
bm.to_csv(pthBM, index = False)

# %%
# \\Pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\benchmark\Benchmark Detail.csv
