# %%
import pandas as pd

# %%
pthPPS = r'P:\Investment Operations\GRC\Compliance\Reporting Requirements\PIM PPSBAL'
df     = pd.read_csv(pthPPS + r'\202403\PPS_MSCI_Constituents_03282024.csv', skiprows = [1])

# %%
# https://stackoverflow.com/questions/41968732/set-order-of-columns-in-pandas-dataframe
df.columns
# Out:
# Index(['provider', 'series code', 'series long name', 'isin', 'cusip', 'sedol',
#        'ticker', 'provider identifier', 'Statpro ISIN', 'Statpro Cusip',
#        'Statpro Sedol', 'security name', 'end date', 'market cap 1',
#        'market cap 2', 'market cap 3', 'market cap 4', 'market cap 5',
#        'weight 1', 'weight 2', 'weight 3', 'weight 4', 'return 1', 'return 2',
#        'return 3', 'return 4', 'return 5', 'price', 'price currency'],
#       dtype='object')

# %%
df = df[['end date', 'series long name', 'isin', 'Statpro ISIN', 'security name', 'price currency', \
         'market cap 3', 'market cap 3', 'market cap 3', 'market cap 1', 'weight 1']]
df.columns = ['datestamp', 'portfolio', 'isin', 'bb_ticker', 'security_name', 'country_name', 'sector', 'industry_group', \
             'industry', 'sub_industry', 'market_cap_usd', 'weight']
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 df = df[['end date', 'series long name', 'isin', 'Statpro ISIN', 'security name', 'price currency', \
#       2          'market cap 3', 'market cap 3', 'market cap 3', 'market cap 1', 'weight 1']]
# ----> 3 df.columns = ['datestamp', 'portfolio', 'isin', 'bb_ticker', 'security_name', 'country_name', 'sector', 'industry_group', \
#       4              'industry', 'sub_industry', 'market_cap_usd', 'weight']
#       5 df
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# ...

# %%
df = df[['end date', 'series long name', 'isin', 'Statpro ISIN', 'security name', 'price currency', \
         'market cap 3', 'market cap 3', 'market cap 3', 'market cap 1', 'weight 1']]
df
# Out:
#       end date               series long name          isin  Statpro ISIN  \
# 0         MSCI                        StatPro          MSCI       StatPro
# 1     20240328  MSCI/WORLD ESG LEADERS/700713  CA0641491075  CA0641491075
# 2     20240328  MSCI/WORLD ESG LEADERS/700713  CA7669101031  CA7669101031
# 3     20240328  MSCI/WORLD ESG LEADERS/700713  US64110D1046  US64110D1046
# 4     20240328  MSCI/WORLD ESG LEADERS/700713  AU000000SEK6  AU000000SEK6
# ...        ...                            ...           ...           ...
# 5485  20240328    MSCI/THE WORLD INDEX/990100  JP3539220008  JP3539220008
# 5486  20240328    MSCI/THE WORLD INDEX/990100  JP3705200008  JP3705200008
# 5487  20240328    MSCI/THE WORLD INDEX/990100  US8793601050  US8793601050
# 5488  20240328    MSCI/THE WORLD INDEX/990100  JP3814000000  JP3814000000
# 5489  20240328    MSCI/THE WORLD INDEX/990100  US1508701034  US1508701034
#
#               security name price currency market cap 3 market cap 3  \
# ...
