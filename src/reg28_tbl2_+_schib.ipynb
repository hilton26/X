# %% [markdown]
# # Run Reg 28 Table 2 and Reg 28 Schedule IB Reports

# %%
import datetime, time

start_time_0 = time.time()

# %run utilities.ipynb

# from utilities import * for this sript to run in VSC
# https://stackoverflow.com/questions/72962306/how-to-use-run-command-to-execute-another-notebook-using-file-path
def reg28_tbl2_schib():
    try:
        # %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/r28_Tbl2_bulk.ipynb"
        # %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/reg28ib.ipynb"
        print("\n", f"Roundtrip time: {timediff(start_time_0, time.time())}")

    except Exception as e:
        print(e)

# %%
reg28_tbl2_schib()

# P:\Working Folders\Hilton\W\Reg_Tests
# P:\Investment Operations\GRC\Compliance\Reg28 and Reg30 Reporting
# P:\Investment Operations\GRC\Compliance\Reporting Requirements\Monthly Reports\2025
# Out:
# ##############################################
# #            START r28_Tbl2_bulk             #
# ##############################################
# Importing libraries ...
# 1.5sec importing libraries completed
#
# Setting up paths ...
# 0.0sec setting up paths completed
#
# Getting report variables ...
# 143 Reg28 files for 31Oct2025 in the reporting folder
#
# 0 funds without corresponding long names:
#
# 0 funds without a completed Reg28 file:
#
#  Report date: 31Oct2025 Reg28
#  Fund (1, i.e., 1 in reporting list less 0 unnamed less 0 without Reg 28 sheets): PPSBAL_C
#
# 31.2sec getting report variables completed
#
# Looping over 1 fund ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 1/1 [00:02<00:00,  2.54s/it]
# 1 Reg 28 Table 2 reports for 31Oct2025 completed and stored here P:\Working Folders\Hilton\W\Reg_Tests
# ##############################################
# #              END r28_Tbl2_bulk             #
# ...
