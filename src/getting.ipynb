# %% [markdown]
# ## Invalid call for scalar access (getting)!
#
# https://stackoverflow.com/questions/67798074/df-at-got-error-valueerror-invalid-call-for-scalar-access-getting

# %%
import pandas as pd

# %%
df = pd.DataFrame({'a':[1,2,3],'b':[1,3,5]})
df
# Out:
#    a  b
# 0  1  1
# 1  2  3
# 2  3  5

# %%
df.at[df['a'] == 1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df.at[df['a'] == 1]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:2575, in _AtIndexer.__getitem__(self, key)
#    2572         raise ValueError("Invalid call for scalar access (getting)!")
#    2573     return self.obj.loc[key]
# -> 2575 return super().__getitem__(key)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:2524, in _ScalarAccessIndexer.__getitem__(self, key)
#    2522         key = (key,)
#    2523     else:
# -> 2524         raise ValueError("Invalid call for scalar access (getting)!")
#    2526 key = self._convert_key(key)
#    2527 return self.obj._get_value(*key, takeable=self._takeable)
#
# ValueError: Invalid call for scalar access (getting)!

# %%
#df.at[df['a'] == 1,'b'] = 0
df.loc[df['a']==1, 'b'] = 0
