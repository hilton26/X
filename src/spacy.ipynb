# %% [markdown]
# # How to use Spacy for noun phrase extraction
#
# https://practicaldatascience.co.uk/data-science/how-to-use-spacy-for-noun-phrase-extraction

# %% [markdown]
# Noun phrase extraction is a Natural Language Processing technique that can be used to identify and extract noun phrases from text. Noun phrases are phrases that function grammatically as nouns in a sentence, and usually include a noun or pronoun as the headword, as well as any associated determiners, adjectives, and modifiers.
#
# For example, given the sentence “The quick brown fox jumps over the lazy dog”, the noun phrases would be “The quick brown fox” and “the lazy dog.”
#
# Noun phrase extraction can be very useful when analysing customer review data during review mining since it reveals more than just the nouns alone. It can be achieved during a range of NLP techniques, including dependency parsing, part of speech tagging, as well as shallow parsing and via Large Language Models and transformers.
#
# In this project we’ll use the Spacy natural language processing library to extract some noun phrases from some text to show how easily it can be achieved.

# %%
# Install the packages
# !pip install -U spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (3.7.4)
# Collecting spacy
#   Obtaining dependency information for spacy from https://files.pythonhosted.org/packages/92/e7/8176484801c67dcd814f141991fe0a3c9b5b4a3583ea30c2062e93d1aa6b/spacy-3.8.7-cp311-cp311-win_amd64.whl.metadata
#   Downloading spacy-3.8.7-cp311-cp311-win_amd64.whl.metadata (28 kB)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy)
#   Obtaining dependency information for thinc<8.4.0,>=8.3.4 from https://files.pythonhosted.org/packages/94/40/7e5e840ac2e835fbf5d87e3ab94df7d678d846aaf28b12d46538ed36bf7f/thinc-8.3.6-cp311-cp311-win_amd64.whl.metadata
#   Downloading thinc-8.3.6-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from spacy) (0.9.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from spacy) (4.66.2)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from spacy) (1.26.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from spacy) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy)
#   Obtaining dependency information for blis<1.4.0,>=1.3.0 from https://files.pythonhosted.org/packages/35/3a/f9414cf9b2c43aad87e8687ad2cdb0e66e996c20288584621a12725e83dd/blis-1.3.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading blis-1.3.0-cp311-cp311-win_amd64.whl.metadata (7.6 kB)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\hilton.netta\appdata\local\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.4)
# Collecting numpy>=1.19.0 (from spacy)
#   Obtaining dependency information for numpy>=1.19.0 from https://files.pythonhosted.org/packages/d5/03/0eade211c504bda872a594f045f98ddcc6caef2b7c63610946845e304d3f/numpy-2.3.2-cp311-cp311-win_amd64.whl.metadata
#   Downloading numpy-2.3.2-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/60.9 kB 1.3 MB/s eta 0:00:01
#      ------------------------------- ------ 51.2/60.9 kB 871.5 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 539.3 kB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users
/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 6.3 MB/s eta 0:00:00
# Downloading numpy-2.3.2-cp311-cp311-win_amd64.whl (13.1 MB)
#    ---------------------------------------- 0.0/13.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/13.1 MB 15.4 MB/s eta 0:00:01
#    -- ------------------------------------- 1.0/13.1 MB 12.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.7/13.1 MB 13.3 MB/s eta 0:00:01
#    ------ --------------------------------- 2.1/13.1 MB 12.3 MB/s eta 0:00:01
#    -------- ------------------------------- 2.7/13.1 MB 12.3 MB/s eta 0:00:01
#    --------- ------------------------------ 3.3/13.1 MB 12.2 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.8/13.1 MB 12.2 MB/s eta 0:00:01
#    ------------- -------------------------- 4.4/13.1 MB 12.2 MB/s eta 0:00:01
#    --------------- ------------------------ 5.1/13.1 MB 12.1 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.7/13.1 MB 12.1 MB/s eta 0:00:01
#    ------------------ --------------------- 6.2/13.1 MB 12.0 MB/s eta 0:00:01
#    ------------------ --------------------- 6.2/13.1 MB 12.0 MB/s eta 0:00:01
#    ------------------ --------------------- 6.2/13.1 MB 12.0 MB/s eta 0:00:01
#    ------------------ --------------------- 6.2/13.1 MB 12.0 MB/s eta 0:00:01
#    -------------------- ------------------- 6.6/13.1 MB 9.2 MB/s eta 0:00:01
#    ------------------------- -------------- 8.3/13.1 MB 10.8 MB/s eta 0:00:01
#    --------------------------- ------------ 8.9/13.1 MB 11.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.6/13.1 MB 10.8 MB/s eta 0:00:01
#    ------------------------------ --------- 10.1/13.1 MB 10.8 MB/s eta 0:00:01
#    ------------------------------- -------- 10.4/13.1 MB 10.4 MB/s eta 0:00:01
#    --------------------------------- ------ 10.9/13.1 MB 10.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.4/13.1 MB 10.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.7/13.1 MB 9.9 MB/s eta 0:00:01
#    ------------------------------------- -- 12.1/13.1 MB 9.8 MB/s eta 0:00:01
#    -------------------------------------- - 12.6/13.1 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  13.0/13.1 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.1 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.1 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.1 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.1 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.1 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.1 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.1 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.1 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.1 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.1 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.1 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.1 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.1 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.1 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  13.1/13.1 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------- 13.1/13.1 MB 5.8 MB/s eta 0:00:00
# Downloading blis-1.3.0-cp311-cp311-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.2 MB 14.9 MB/s eta 0:00:01
#    ------ --------------------------------- 1.0/6.2 MB 12.6 MB/s eta 0:00:01
#    -------- ------------------------------- 1.3/6.2 MB 12.0 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.8/6.2 MB 10.4 MB/s eta 0:00:01
#    -------------- ------------------------- 2.3/6.2 MB 10.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 2.7/6.2 MB 10.7 MB/s eta 0:00:01
#    ------------------- -------------------- 3.1/6.2 MB 9.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.6/6.2 MB 10.0 MB/s eta 0:00:01
#    ------------------------- -------------- 4.0/6.2 MB 9.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.4/6.2 MB 9.6 MB/s eta 0:00:01
#    ------------------------------- -------- 4.9/6.2 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.4/6.2 MB 9.8 MB/s eta 0:00:01
#    ------------------------------------ --- 5.7/6.2 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------  6.2/6.2 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------  6.2/6.2 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  6.2/6.2 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  6.2/6.2 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  6.2/6.2 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 7.2 MB/s eta 0:00:00
# Installing collected packages: numpy, blis, thinc, spacy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: blis
#     Found existing installation: blis 0.7.11
#     Uninstalling blis-0.7.11:
#       Successfully uninstalled blis-0.7.11
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.2.3
#     Uninstalling thinc-8.2.3:
#       Successfully uninstalled thinc-8.2.3
#   Attempting uninstall: spacy
#     Found existing installation: spacy 3.7.4
#     Uninstalling spacy-3.7.4:
#       Successfully uninstalled spacy-3.7.4
# Successfully installed blis-1.3.0 numpy-2.3.2 spacy-3.8.7 thinc-8.3.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# astropy 5.3.4 requires numpy<2,>=1.21, but you have numpy 2.3.2 which is incompatible.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.3.2 which is incompatible.
# fastai 2.7.15 requires torch<2.4,>=1.10, but you have torch 2.5.1 which is incompatible.
# langchain 0.3.7 requires numpy<2,>=1; python_version < "3.12", but you have numpy 2.3.2 which is incompatible.
# langchain-community 0.3.5 requires numpy<2,>=1; python_version < "3.12", but you have numpy 2.3.2 which is incompatible.
# numba 0.59.1 requires numpy<1.27,>=1.22, but you have numpy 2.3.2 which is incompatible.
# pywavelets 1.5.0 requires numpy<2.0,>=1.22.4, but you have numpy 2.3.2 which is incompatible.
# scipy 1.13.0 requires numpy<2.3,>=1.22.4, but you have numpy 2.3.2 which is incompatible.
# tensorflow-intel 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.3.2 which is incompatible.
# torchvision 0.17.2 requires torch==2.2.2, but you have torch 2.5.1 which is incompatible.
# Collecting en-core-web-sm==3.8.0
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl
#   WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl
#   WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl
#   WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)'))': /explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl
# ERROR: Could not install packages due to an OSError: HTTPSConnectionPool(host='github.com', port=443): Max retries exceeded with url: /explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1006)')))

# %% [markdown]
# Import the packages

# %%
import spacy

# %% [markdown]
# Import Spacy then load the en_core_web_sm model using spacy.load(). Assign the model object to a variable called nlp. We’ll now be able to pass data to the nlp model and perform various Natural Language Processing tasks.

# %%
nlp = spacy.load("en_core_web_sm")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 nlp = spacy.load("en_core_web_sm")
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\spacy\__init__.py:52, in load(name, vocab, disable, enable, exclude, config)
#      28 def load(
#      29     name: Union[str, Path],
#      30     *,
#    (...)
#      35     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      36 ) -> Language:
#      37     """Load a spaCy model from an installed package or a local path.
#      38
#      39     name (str): Package name or model path.
#    (...)
#      50     RETURNS (Language): The loaded nlp object.
#      51     """
# ---> 52     return util.load_model(
#      53         name,
#      54         vocab=vocab,
#      55         disable=disable,
#      56         enable=enable,
#      57         exclude=exclude,
#      58         config=config,
#      59     )
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\spacy\util.py:484, in load_model(name, vocab, disable, enable, exclude, config)
#     482 if name in OLD_MODEL_SHORTCUTS:
#     483     raise IOError(Errors.E941.format(name=name, full=OLD_MODEL_SHORTCUTS[name]))  # type: ignore[index]
# --> 484 raise IOError(Errors.E050.format(name=name))
#
# OSError: [E050] Can't find model 'en_core_web_sm'. It doesn't seem to be a Python package or a valid path to a data directory.

# %% [markdown]
# ### Create a document to analyse
# Now we need to create a variable or document that contains the text we want Spacy to analyse. We’ll store a sentence containing some noun phrases in a variable called text.

# %%
text = """
The data scientist hurriedly wrote some code on their Linux workstation to get everything completed before the deadline. 
"""

# %% [markdown]
# ### Pass the text to Spacy
#
# Next we need to pass our text variable to the nlp() model and assign the output to a variable so we can parse the results returned. We can do this by entering doc = nlp(text).

# %%
doc = nlp(text)

# %% [markdown]
# ### Extract nouns and noun phrases
#
# To extract nouns and noun phrases from the doc returned by Spacy we can use a couple of list comprehensions. The first one returns a list of values where the token.pos_ value is NOUN, which gives us a list of the nouns in our text.

# %%
print("Nouns:", [token.lemma_ for token in doc if token.pos_ == "NOUN"])
# Out:
# Nouns: ['data', 'scientist', 'code', 'workstation', 'deadline']

# %% [markdown]
# The second list comprehension extracts the noun phrases from the chunk.text using the noun_chunks feature of Spacy. This returns a list containing all the noun phrases Spacy extracted from the text.

# %%
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
# Out:
# Noun phrases: ['\nThe data scientist', 'some code', 'their Linux workstation', 'everything', 'the deadline']
