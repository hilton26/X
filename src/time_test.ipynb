# %%
# import libraries
import datetime, time
import schedule, os
import pandas as pd
# from datetime import datetime
# from time_diff_function import timediff
# %run utilities.ipynb

# %%
import datetime
now = datetime.datetime.now()
now
# Out:
# datetime.datetime(2025, 5, 19, 13, 43, 21, 102735)

# %%
# datetime.datetime(2009, 1, 6, 15, 8, 24, 78915)
print(datetime.datetime.now().strftime("%Hh%M:%Ss %a %d %b %Y"))
# Out:
# 13h46:53s Mon 19 May 2025

# %%
        print(f'{datetime.datetime.now().strftime("%Hh%M:%Ss %a %d %b %Y")}:\
              x was completed at   ')
# Out:
# 13h49:52s Mon 19 May 2025:      x was completed at
