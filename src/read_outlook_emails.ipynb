# %%
import requests


def get_access_token():
    """Gets an access token for the Microsoft Graph API."""

    url = "https://login.microsoftonline.com/common/oauth2/token"
    data = {
        "grant_type": "client_credentials",
        "client_id": "client_key",
        "client_secret":"client_secret",
        "resource": "https://graph.microsoft.com/"
    }
    response = requests.post(url, data=data)
    if response.status_code == 200:
        return response.json()["access_token"]
    else:
        # print(response.status_code)
        return None


token = get_access_token()
r = requests.get("https://graph.microsoft.com/v1.0/me/messages",
                 headers={"Authorization": "Bearer " + token})

if r.status_code == 200:
    for message in r.json():
        print(message["subject"])
else:
    print("Authentication Failed")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 24
#      19         return None
#      22 token = get_access_token()
#      23 r = requests.get("https://graph.microsoft.com/v1.0/me/messages",
# ---> 24                  headers={"Authorization": "Bearer " + token})
#      26 if r.status_code == 200:
#      27     for message in r.json():
#
# TypeError: can only concatenate str (not "NoneType") to str

# %%
# !jupyter nbconvert --to script read_outlook_emails.ipynb
# Out:
# [NbConvertApp] Converting notebook read_outlook_emails.ipynb to script
# [NbConvertApp] Writing 921 bytes to read_outlook_emails.py
