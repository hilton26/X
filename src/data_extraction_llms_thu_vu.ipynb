# %%
# !pip install --upgrade --quiet langchain langchain-community langchain-openai chromadb
# !pip install --upgrade --quiet pypdf pandas streamlit python-dotenv

# %%
# import langchain modules
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain.vectorstores import Chroma
from langchain_core.runnables import RunnablePassthrough
from langchain_core.prompts import ChatPromptTemplate
#from langchain_core.pydantic_v1 import BaseModel, Field
#https://github.com/langchain-ai/langchain/issues/8724
from pydantic import BaseModel, Field

# Other modules and packages
import os
import tempfile
import streamlit as st
import pandas as pd
from dotenv import load_dotenv
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 # import langchain modules
# ----> 2 from langchain.document_loaders import PyPDFLoader
#       3 from langchain.text_splitter import RecursiveCharacterTextSplitter
#       4 from langchain_openai import OpenAIEmbeddings, ChatOpenAI
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\langchain\document_loaders\__init__.py:192
#      22 if TYPE_CHECKING:
#      23     from langchain_community.document_loaders import (
#      24         AcreomLoader,
#      25         AirbyteCDKLoader,
#    (...)
#     189         YuqueLoader,
#     190     )
# --> 192 from langchain_core.document_loaders import Blob, BlobLoader
#     194 # For backwards compatibility
#     195 _old_to_new_name = {
#     196     "PagedPDFSplitter": "PyPDFLoader",
#     197     "TelegramChatLoader": "TelegramChatFileLoader",
#     198 }
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\langchain_core\document_loaders\__init__.py:1
# ----> 1 from langchain_core.document_loaders.base import BaseBlobParser, BaseLoader
#       2 from langchain_core.document_loaders.blob_loaders import Blob, BlobLoader, PathLike
#       3 from langchain_core.document_loaders.langsmith import LangSmithLoader
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\langchain_core\document_loaders\base.py:9
#       6 from collections.abc import AsyncIterator, Iterator
#       7 from typing import TYPE_CHECKING, Optional
# ----> 9 from langchain_core.documents import Document
#      10 from langchain_core.runnables import run_in_executor
#      12 if TYPE_CHECKING:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\langchain_core\documents\__init__.py:6
#       1 """**Document** module is a collection of classes that handle documents
#       2 and their transformations.
#       3
#       4 """
# ----> 6 from langchain_core.documents.base import Document
#       7 from langchain_core.documents.compressor import BaseDocumentCompressor
#       8 from langchain_core.documents.transformers import BaseDocumentTransformer
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\langchain_core\documents\base.py:10
#       7 from pathlib import PurePath
#       8 from typing import Any, Literal, Optional, Union, cast
# ---> 10 from pydantic import ConfigDict, Field, field_validator, model_validator
#      12 from langchain_core.load.serializable import Serializable
#      14 PathLike = Union[str, PurePath]
#
# ImportError: cannot import name 'field_validator' from 'pydantic' (C:\Users\hilton.netta\AppData\Local\anaconda3\Lib\site-packages\pydantic\__init__.cp311-win_amd64.pyd)
