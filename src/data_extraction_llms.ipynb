# %% [markdown]
# ## Extracting Structured Data From PDFs | Full Python AI project for beginners (ft Docker)
# https://www.youtube.com/watch?v=EFUE4DHiAPM

# %%
# install libraries
# !pip3 install --upgrade --quiet langchain langchain-community langchain-openai chromadb
# !pip3 install --upgrade --quiet pypdf pandas streamlit python-dotenv

# langchain - a flexibkle framework for building llm applications
# langchain-community -  essential 3rd party integrations for langchain
# langchain-openai - package which connects langchain with openai
# chromadb - an open source vector database
# pypdf - a package for reading and parsing pdf documents in python
# pandas - for data wrangling
# streamplit - a package for building quick web apps in python
# python-dotenv - a package for setting environment variables in python
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# anaconda-cloud-auth 0.1.3 requires pydantic<2.0, but you have pydantic 2.9.2 which is incompatible.

# %%
# import langchain modules
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain.vectorstores import Chroma
from langchain_core.runnables import RunnablePassthrough
from langchain_core.prompts import ChatPromptTemplate
#from langchain_core.pydantic_v1 import BaseModel, Field
#https://github.com/langchain-ai/langchain/issues/8724
from pydantic import BaseModel, Field

# Other modules and packages
import os
import tempfile
import streamlit as st
import pandas as pd
from dotenv import load_dotenv
