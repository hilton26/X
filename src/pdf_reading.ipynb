# %% [markdown]
# # **Extract text, links, images, tables from Pdf with Python | PyMuPDF, PyPdf, PdfPlumber tutorial**
#
# https://www.youtube.com/watch?v=G0PApj7YPBo
#
# https://pypdf.readthedocs.io/en/stable/
#
# https://www.ibm.com/docs/en/db2-event-store/2.0.0?topic=notebooks-markdown-jupyter-cheatsheet

# %%
# libraries, libraries!

# %run utilities.ipynb # for the timediff() function
# !pip install  pypdf
from pypdf import PdfReader
from docx import Document  # https://python-docx.readthedocs.io/en/latest/
from tqdm import tqdm
import os
import pandas as pd

# %%
# set path to the pdf to be parsed
start_time = time.time()

print("Saving the pdf text to Word ...", "\n")

# get the pdf file path and name
pthPy = r"P:\Investment Operations\GRC\Compliance\Daily\py_reports.xlsm"  # variables stored here
df = pd.read_excel(pthPy, sheet_name="pdf", usecols="A", header=None, nrows=1)
path_pdf = df.iloc[0, 0].replace('"', "")
# print(path_pdf)

# apply the pdf reader to the pdf
reader = PdfReader(path_pdf)

# print stats on number of pdf pages
lx = len(reader.pages)
print("", f"{lx} page{'' if lx == 1 else 's'} in the pdf")

# print name of the eventual Word doc
# https://www.w3schools.com/python/ref_string_rfind.asp#:~:text=The%20rfind()%20method%20finds,as%20the%20rindex()%20method.
doc_name = path_pdf[path_pdf.rfind("\\") + 1 : path_pdf.rfind(".")] + ".docx"
print("", os.path.join(r"P:\Working Folders\Hilton\W\Reg_Tests", f"{doc_name}"), "\n")

# create a Word document to hold the extracted pdf text https://www.youtube.com/watch?v=re-rBqvDUPM
doc = Document()

# get text from every page in the pdf and add it to the Word doc
for page in tqdm(range(len(reader.pages))):
    pg = reader.pages[page]
    text = pg.extract_text()
    # print(text)
    doc.add_paragraph(text)
    # doc.add_page_break()

doc.save(
    os.path.join(r"P:\Working Folders\Hilton\W\Reg_Tests", f"{doc_name}")
)  # save in python exports folder
doc.save(
    path_pdf[0 : path_pdf.rfind("\\") + 1] + f"{doc_name}"
)  # save in the local pdf folder

print(f"{timediff(start_time, time.time())} saving the pdf text to Word")
print(path_pdf[0 : path_pdf.rfind("\\") + 1] + f"{doc_name}")
# Out:
# Saving the pdf text to Word ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 13
#       9 path_pdf   = df.iloc[0, 0]
#      10 # print(path_pdf)
#      11
#      12 # apply the pdf reader to the pdf
# ---> 13 reader     = PdfReader(path_pdf)
#      15 # print stats on number of pdf pages
#      16 lx = len(reader.pages)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pypdf\_reader.py:133, in PdfReader.__init__(self, stream, strict, password)
#     129 self._page_id2num: Optional[Dict[Any, Any]] = None
#     131 self._validated_root: Optional[DictionaryObject] = None
# --> 133 self._initialize_stream(stream)
#     135 self._override_encryption = False
#     136 self._encryption: Optional[Encryption] = None
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pypdf\_reader.py:151, in PdfReader._initialize_stream(self, stream)
#     149 self._stream_opened = False
#     150 if isinstance(stream, (str, Path)):
# --> 151     with open(stream, "rb") as fh:
#     152         stream = BytesIO(fh.read())
#     153     self._stream_opened = True
#
# OSError: [Errno 22] Invalid argument: '"P:\\Investment Operations\\GRC\\Compliance\\UCITS\\UCITS_SI_352_of_2011.pdf"'

# %%
# !jupyter nbconvert --to script pdf_reading.ipynb
# Out:
# [NbConvertApp] Converting notebook pdf_reading.ipynb to script
# [NbConvertApp] Writing 2364 bytes to pdf_reading.py
