# %% [markdown]
# ## Python RAG Tutorial (with Local LLMs): AI For Your PDFs
#
# video - https://www.youtube.com/watch?v=2TJxpyO3ei4
# langchain docs - https://docs.langchain.com/oss/python/integrations/document_loaders

# %%
# 4min01
from langchain.document_loaders.pdf import PyPDFDirectoryLoader
DATA_PATH = r"\\PIM-CPT-FS.prescient.local\PIM-Documents$\Working Folders\Hilton\Ex\Legislation\201408 CISCA BN90 UT INVESTMENT LIMITS.pdf"
def load_documents():
    document_loader = PyPDFDirectoryLoader(DATA_PATH)
    return document_loader.load

# %%
load_documents()
# Out:
# <bound method PyPDFDirectoryLoader.load of <langchain_community.document_loaders.pdf.PyPDFDirectoryLoader object at 0x00000219134C3310>>
