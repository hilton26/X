# %% [markdown]
# # Run Reg 28 Table 2, Reg 28 Schedule IB, and MonthEnd17 Reports

# %%
import time
start_time_r28 = time.time()

from utilities import timediff

# from utilities import * for this sript to run in VSC
# https://stackoverflow.com/questions/72962306/how-to-use-run-command-to-execute-another-notebook-using-file-path
def tbl2_schib_me17():
    try:
        # %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/month_end_updates.ipynb" # update report date and ZAR/USD rate
        # %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/r28_Tbl2_bulk.ipynb"     # generate Reg 28 Table 2 reports
        # %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/reg28_ib.ipynb"           # generate Reg 28 Schedule IB reports
        # %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/monthend17.ipynb"        # generate "monthend-17" client reports
        print("\n", f"{timediff(start_time_r28, time.time())} roundtrip for Reg 28 Table 2 + Reg 28 Schedule IB + Month-end 17 reports")

    except Exception as e:
        print(e)

# %%
tbl2_schib_me17()

# P:\Working Folders\Hilton\W\Reg_Tests
# P:\Investment Operations\GRC\Compliance\Reg28 and Reg30 Reporting
# P:\Investment Operations\GRC\Compliance\Reporting Requirements\Monthly Reports\2025
# Out:
# ##############################################
# #            START r28_Tbl2_bulk             #
# ##############################################
# Importing libraries ...
#  1.2sec importing libraries completed
#
# Setting up paths ...
#  0.0sec setting up paths completed
#
# Getting report variables ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_24552\710943611.py:11
#       9 df = pd.read_excel(pthPy, sheet_name = 'r28_tbl2', usecols = 'D,F')
#      10 k = df.iloc[0,1]
# ---> 11 rptDate  = k if isinstance(k, datetime) else prior_month_end(datetime.today())
#      12 rpt_Type = df.iloc[0,0]
#      14 # get list of completed Reg28 files in the reporting folder
#
# NameError: name 'prior_month_end' is not defined
# name 'prior_month_end' is not defined
