# %%
# import libraries
import schedule
from datetime import datetime
import time
from time_diff_function import timediff

# %%
def statpro_cleanup():
    try:
        #https://stackoverflow.com/questions/72962306/how-to-use-run-command-to-execute-another-notebook-using-file-path
        # %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/statpro_eagle_file_cleanup.ipynb"
        # %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/statpro_inet_file_cleanup.ipynb" 
        # %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/statpro_get_mtm_data.ipynb"
        # %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/statpro_update_bm.ipynb"
               
    except Exception as e:
        print(e)

# %%
# schedule
t = '11:26'
schedule.every().monday.   at(t).do(lambda: statpro_cleanup())
schedule.every().tuesday.  at(t).do(lambda: statpro_cleanup())
schedule.every().wednesday.at(t).do(lambda: statpro_cleanup())
schedule.every().thursday. at(t).do(lambda: statpro_cleanup())
schedule.every().friday.   at(t).do(lambda: statpro_cleanup())

while True:
    schedule.run_pending()
    time.sleep(10)
# Out:
# Amending \eagle\.. files before StatPro run ...
# Amending \eagle\.. files before StatPro run completed: 0d 0hr 0min 28.0sec
# Cleaning up inet_icdf and inet-eod files ...
# \\Pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\inet-icdf\copy\ICDFXML20240627-2200.XML
# \\Pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\inet-eod\copy\DCC020240627.dat
# \\Pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\inet-eod\copy\DFC020240627.dat
# \\Pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\inet-eod\copy\DPC020240627.dat
# Cleaning up inet_icdf and inet-eod files completed: 0d 0hr 0min 5.0sec
#  Latest BESA file date : Thu 27 Jun 2024, 303 entries
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File ~\AppData\Local\Temp\ipykernel_21200\1405134134.py:2
#       1 # save the new MarketDataOverrides.xls file
# ...

# %%
# \\Pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\eagle
