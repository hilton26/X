# %%
# import libraries
from datetime import datetime
import time
from time_diff_function import timediff

# %%
def statpro_eagle_and_inet_file_cleanup():
    try:
        #https://stackoverflow.com/questions/72962306/how-to-use-run-command-to-execute-another-notebook-using-file-path
        # %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/statpro_eagle_file_cleanup.ipynb"   
        # %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/statpro_inet_file_cleanup.ipynb"      
    except Exception as e:
        print(e)

# %%
start_time = datetime.now()
print('Configuring eagle and inet files ...')

statpro_eagle_and_inet_file_cleanup()

print(f'Configuring eagle and inet files completed: {timediff(start_time, time.time())}')
# Out:
# Configuring eagle and inet files ...
# Amending \eagle\.. files before StatPro run ...
# Amending \eagle\.. files before StatPro run completed: 0d 0hr 0min 4.0sec
# Cleaning up inet_icdf and inet-eod files ...
# \\Pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\inet-icdf\copy\ICDFXML20240411-2200.XML
# \\Pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\inet-eod\copy\DCC020240411.dat
# \\Pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\inet-eod\copy\DFC020240411.dat
# \\Pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\inet-eod\copy\DPC020240411.dat
# Cleaning up inet_icdf and inet-eod files completed: 0d 0hr 0min 7.0sec
# Configuring eagle and inet files completed: 0d 0hr 0min 7.0sec

# %%
# \\Pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\eagle
