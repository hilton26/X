# %%
### Prepare the GEMEMDC weekly report for the previous Friday's close

import time

# libraries, libraries!
import os
import subprocess
from constants import pre_issuers_1, issuers_1
from utilities import timediff

# from utilities import * for this sript to run in VSC
# https://stackoverflow.com/questions/72962306/how-to-use-run-command-to-execute-another-notebook-using-file-path
def gemsmed_rpt():
    try:
        # get and process gemsmed report information"
        print("Step 1 of 2: gemsmed_pre_issuers_1.py is running ...")
        start_time_1 = time.time()
        # %run "$pre_issuers_1"
        print(f"  {timediff(start_time_1, time.time())} to complete gemsmed_pre_issuers_1.py/n")
        
        # run the Reg 28 categorisation scripts issuers_1.py, issuers_2.py, and issuers_3.py
        print("\nStep 2 of 2: issuers_1.py is running ...")        
        start_time_2 = time.time()
        # %run "$issuers_1"
        print(f"  {timediff(start_time_2, time.time())} to complete issuers_1.ipynb/n")

    except Exception as e:
        print(e)

# execute the function
start_time_gemsmed = time.time()

gemsmed_rpt()

print("\n", f"{timediff(start_time_gemsmed, time.time())} GEMDMEDC roundtrip time")
# Out:
# Step 1 of 2: gemsmed_pre_issuers_1.py is running ...
# ###################################
# # START 1/2 gemsmed_pre_issuers_1 #
# ###################################
# Importing libraries to get GEMSMED_C holdings ...
#  0.0sec importing libraries to get GEMSMED_C holdings
#
# Getting the report parameters ...
#
#  Fri 06 Mar 2026 for 1 fund:
#   GEMSMEDC
#
# Files expected:
#  C:\Users\hilton.netta\Downloads\R28I GEMSMEDC(1) 06Mar2026.csv
#  C:\Users\hilton.netta\Downloads\DERV GEMSMEDC(1) 06Mar2026.csv
#
# 3.5sec getting the report parameters
#
# Extracting and saving the fund holdings and derivatives ...
#
# C:\Users\hilton.netta\Downloads\R28I GEMSMEDC(1) 06Mar2026.csv exists
# C:\Users\hilton.netta\Downloads\DERV GEMSMEDC(1) 06Mar2026.csv exists
#
#  0.0sec extracting and saving the fund holdings and derivatives
#
# Preparing the combined holdings and derivatives dataframes ...
#
#  Converting numerical columns from type string to type float ...
# ...

# %%
# !jupyter nbconvert --to script gemsmed_reporting.ipynb # convert from .ipynb to .py
