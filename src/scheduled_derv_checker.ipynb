# %% [markdown]
# # Derivative Cover Reporting

# %% [markdown]
# ### Input:
#
# \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Daily\py_reports, "downloader" tab
#
# ### Dependencies:
# C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/derv_checker_downloading.ipynb "dervs" tab
#
# C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/derv_checker_compiling.ipynb "dervs" tab

# %%
# define the report function
def derv_run():
    import time
    start_time_roundtrip = time.time()
    
    # libraries, libraries!
    import os, schedule
    import pandas as pd
    import subprocess
    from datetime import datetime
    from constants import derv_checker
    from utilities import timediff

    # %run "$derv_checker"

    #print(rf"\n{timediff(start_time_roundtrip, time.time())} roundtrip time to download and complete {rptDate.strftime('%d %b %Y')} derivative cover reports")

# %%
# list the frequency of runs

from datetime import datetime, timedelta

# list of times every 15 minutes from 8:45 AM to 17:30
start = datetime.strptime("08:30", "%H:%M")
end = datetime.strptime("18:30", "%H:%M")
increment = 15   # every 15 minutes

times = []
current = start
while current <= end:
    times.append(current.strftime("%H:%M"))
    current += timedelta(minutes=increment)

print(f"Scheduled run times with a {increment} minute increment:\n {(',').join(times)}")
# Out:
# Scheduled run times with a 15 minute increment:
#  08:30,08:45,09:00,09:15,09:30,09:45,10:00,10:15,10:30,10:45,11:00,11:15,11:30,11:45,12:00,12:15,12:30,12:45,13:00,13:15,13:30,13:45,14:00,14:15,14:30,14:45,15:00,15:15,15:30,15:45,16:00,16:15,16:30,16:45,17:00,17:15,17:30,17:45,18:00,18:15,18:30

# %%
# scheduler    https://pypi.org/project/schedule/
import schedule, time
         
for t in times:
    schedule.every().monday.   at(t).do(lambda: derv_run())
    schedule.every().tuesday.  at(t).do(lambda: derv_run())
    schedule.every().wednesday.at(t).do(lambda: derv_run())
    schedule.every().thursday. at(t).do(lambda: derv_run())
    schedule.every().friday.   at(t).do(lambda: derv_run())

while True:
    schedule.run_pending()
    time.sleep(10)
# Out:
# Deriving file names ...
# 10h45:07s Tue 08 Sep 2026: \Free Cover.xlsm for Mon 07 Sep 2026 was completed at Tue Sep  8 09:45:32 2026
# \n 2.8sec to run derv_check(), now on to getting the cash transaction reports
# Deriving file names ...
# 11h11:59s Tue 08 Sep 2026: \Free Cover.xlsm for Mon 07 Sep 2026 was completed at Tue Sep  8 09:45:32 2026
# \n 2.2sec to run derv_check(), now on to getting the cash transaction reports
# Deriving file names ...
# 11h17:18s Tue 08 Sep 2026: \Free Cover.xlsm for Mon 07 Sep 2026 was completed at Tue Sep  8 09:45:32 2026
# \n 2.5sec to run derv_check(), now on to getting the cash transaction reports
# Deriving file names ...
# 11h38:35s Tue 08 Sep 2026: \Free Cover.xlsm for Mon 07 Sep 2026 was completed at Tue Sep  8 09:45:32 2026
# \n 2.4sec to run derv_check(), now on to getting the cash transaction reports
# Deriving file names ...
# 11h52:55s Tue 08 Sep 2026: \Free Cover.xlsm for Mon 07 Sep 2026 was completed at Tue Sep  8 09:45:32 2026
# \n 2.2sec to run derv_check(), now on to getting the cash transaction reports
# Deriving file names ...
# 12h00:15s Tue 08 Sep 2026: \Free Cover.xlsm for Mon 07 Sep 2026 was completed at Tue Sep  8 09:45:32 2026
# \n 8.9sec to run derv_check(), now on to getting the cash transaction reports
# Deriving file names ...
#