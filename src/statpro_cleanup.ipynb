# %%
# import libraries
import schedule
from datetime import datetime
import time
from time_diff_function import timediff

# %%
def statpro_cleanup():
    try:
        #https://stackoverflow.com/questions/72962306/how-to-use-run-command-to-execute-another-notebook-using-file-path
        # %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/statpro_eagle_file_cleanup.ipynb"
        # %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/statpro_inet_file_cleanup.ipynb" 
        # %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/statpro_get_mtm_data.ipynb"
        # %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/statpro_update_bm.ipynb"
                
    except Exception as e:
        print(e)

# %%
statpro_cleanup()
# Out:
# Amending \eagle\.. files before StatPro run ...
# Amending \eagle\.. files before StatPro run completed: 0d 0hr 0min 16.0sec
# Cleaning up inet_icdf and inet-eod files ...
# \\Pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\inet-icdf\ICDFXML20240620-2200.XML
# \\Pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\inet-icdf\copy\ICDFXML20240620-2200.XML
# \\Pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\inet-eod\DCC020240620.dat
# \\Pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\inet-eod\DFC020240620.dat
# \\Pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\inet-eod\DPC020240620.dat
# \\Pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\inet-eod\copy\DCC020240620.dat
# \\Pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\inet-eod\copy\DFC020240620.dat
# \\Pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\inet-eod\copy\DPC020240620.dat
# Cleaning up inet_icdf and inet-eod files completed: 0d 0hr 0min 19.0sec
#  Latest BESA file date : Thu 20 Jun 2024, 302 entries
# C:\Users\hilton.netta\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# C:\Users\hilton.netta\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Conditional Formatting extension is not supported and will be removed
#   for idx, row in parser.parse():
# C:\Users\hilton.netta\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# C:\Users\hilton.netta\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Conditional Formatting extension is not supported and will be removed
#   for idx, row in parser.parse():
# 5.630519879743728 9.933604248080893 10.213610299484733
# C:\Users\hilton.netta\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# C:\Users\hilton.netta\AppData\Local\anaconda3\Lib\site-packages\openpyxl\worksheet\_read_only.py:81: UserWarning: Conditional Formatting extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
# \\Pim-cpt-statpro\Plugins\Profiles\PIM\DataStage\Data\eagle
