# %%
def settlement_cash_check():
    # %run utilities.py
    from datetime import datetime
    import sys
    import pandas as pd
    # import datetime, sys
    # import pandas as pd
    
    start_time_0 = time.time()
    try:
        if datetime.today().weekday() == 0:
            #https://stackoverflow.com/questions/72962306/how-to-use-run-command-to-execute-another-notebook-using-file-path
            # %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/settlement_cash.ipynb"
            
    except Exception as e:
        print(e)

# %%
# scheduler    https://pypi.org/project/schedule/
import schedule, time

t = '12:15'
schedule.every().monday.   at(t).do(lambda: settlement_cash_check())
schedule.every().tuesday.  at(t).do(lambda: settlement_cash_check())
schedule.every().wednesday.at(t).do(lambda: settlement_cash_check())
schedule.every().thursday. at(t).do(lambda: settlement_cash_check())
schedule.every().friday.   at(t).do(lambda: settlement_cash_check())

while True:
    schedule.run_pending()
    time.sleep(10)

# %%
# P:\Investment Operations\GRC\Compliance\Overdrafts
