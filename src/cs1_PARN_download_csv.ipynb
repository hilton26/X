# %%
print('\n\n#########################################')
print('#                                       #')
print('#   START cs1_PARN_download_csv.ipynb   #')
print('#                                       #')
print('#########################################\n\n')
# Out:
# #########################################
# #                                       #
# #   START cs1_PARN_download_csv.ipynb   #
# #                                       #
# #########################################

# %%
import time
start_time                   = time.time()
start_time_cs1_PARN_download = start_time

# libraries, libraries!
print('Importing libraries ...')
from datetime import datetime
import pandas as pd
import os
from pathlib import Path
from tqdm import tqdm, notebook
from constants import pthPy, pth_dl
from utilities import timediff, last_working_day, prior_month_end, osprey, batch_list

print(f' {timediff(start_time, time.time())} importing libraries\n')
# Out:
# Importing libraries ...
#  1.6sec importing libraries

# %%
# get inputs to pass to Eagle
start_time = time.time()
print('Collecting input data ...')

# get fund codes from 'arc' tab of the py_report.xlsm sheet
df      = pd.read_excel(pthPy, sheet_name="arc", usecols="N").dropna()
funds   = df.iloc[:,0].apply(str.upper)

# get report date
df1     = pd.read_excel(pthPy, sheet_name="arc", usecols="S", nrows = 3)
k       = df1.iloc[1,0]
rptDate = k.date() if k == k else prior_month_end(datetime.today()).date()

# print inputs
print('\n',f'PARN CS1 fund report{"" if len(funds) == 1 else "s"} to be downloaded as at {rptDate.strftime("%A %d %b %Y")}', '\n', \
f'{len(funds)} fund{"" if len(funds) == 1 else "s"}: ','\n',f"{(', ').join(funds)}")
print(f'\n{timediff(start_time, time.time())} collecting input data\n')
# Out:
# Collecting input data ...
#
#  PARN CS1 fund reports to be downloaded as at Monday 31 Aug 2026
#  188 funds:
#  3BBCIINC, ABMMBND, ADRRC, ADVMB, ADVMM, AFGBAL, AFLBAL, AFLMMF, AFPFLB, AMMARF, AMPBQP, ASBTOS, ASHFLX, BCICEF, BCIFIF, BONMMF, BPROV, CCNPF, CCTCSH, CMPFCASH, CMPFFLEX, CMPFINC, CSIRBQP, ECICBAL, ECICBALC, ELCIPF, ENGENIP, ENGENMBF, FEMPBF, GACASH, GAEMBF, GEMSMED, GEMSMEDC, GMRETF, GMRETF2, GRFINV, GTCWP2, HOLADC, HOLDINC, HOLDINCR, HOLEQU, HOLIDC, HOLMMF, HOLYPF, HOSMED, IJGCOR, IJGIPF, IJGMMF, IMPALA, IMPBAL_C, IMPREF, IMPREF_C, IPCASH, IPIPF, ISPFP, LEZAFFI, LEZALDI, LIBTAA, LNBINS, LNBLIN, LPIIFTAA, MASAINC, MASAINRF, MASAMMF, MASASI, MASASIRF, MEDINC, MGFYQP, MOMABIL, MOMBBF, MOMBBRF, MOMFLX, MOMFXB, MOMIPF, MOMPRET, MOMTAAHI, MOMTAALI, MOMTAAMI, MULTICH, MWPFEQU, MWPFILB, MYQIP, NESEQU, NFMWAGG, NFMWEQU, NGKINC, OMLMMF, OMMAIF, PABS, PANDA, PBFETF, PBNDQ, PCBF, PCCEF, PCEQTF, PCGEARF, PCGEF, PCMMF, PCSHQ, PEQ, PEQF, PETFIP, PEYF, PFFIF, PGARFF, PGBEUR, PGBF, PGBGBP, PGBZAR, PGCBF, PGCEF, PGEMZAR, PGIF, PGIP_I, PGIPFA, PGIPZAR, PGPCEM_C, PGPCGE_C, PGPCZAR, PGPGARF, PGPGBF_C, PGPGIF_C, PGPRF_C, PGPRGBP, PICPROV, PIF, PIMBAL, PIMEVO, PIMIDF, PIPF, PIPFP, PLMED, PLPRNA, PMMF, POIF_C, POIFEQT, PORFIP, PPEF, PPOS, PPSBAL, PPSBAL_C, PPSFLEX, PPSNAM, PPSRBNQ, PPWEQU, PRLMMF, PRPABF, PRPDBF, PSGBF, PSIF, PSILB, PSPAM, PSSPFEQU, PSTIF, PTIF, PWMIPF_P, QIFFGIF, SAAMCAU, SAAMINC, SAAMMOD, SABCCSHF, SASRMM, SDINCPM, SILAIF, SILEQF, SISLP, SISMMF, SMMAIF, SMMIBF, SMMILP, SMMRRF, SNPFEQU, SSLSP, STBFIP, SYMMMF, TRFINC, TRFWLTH, UCT3YQ, UCTINC, UCTRFBAL, UCTRFINC, UNISABAL, UNVFRS, UOZMMF, USAIPF, UWRFCON, UWRFGRO, VMPTAA_C
#
# 4.9sec collecting input data

# %%
# download the PARN reports in batches
num_batches = 2 if len(funds) > 1 else 1
batch_size = int(len(funds) / num_batches)
batches = batch_list(funds, batch_size = min(len(funds),batch_size))
batch_filepaths = []
for index, batch in tqdm(enumerate(batches, start = 1)):
    fln = f"{index}_of_{len(batches)}_CS1"
    filename = f"PARN {fln}({len(batch)}) {rptDate.strftime('%#d%b%Y')}.csv"
    s = "" if len(batch) == 1 else "s"
    print(f"{filename}, a batch of {len(batch)} file{s}:\n   {(', ').join(batch)}\n")    
    # print(f" {len(batch)} files:\n   {(', ').join(batch)}\n")
    batch_filepath = os.path.join(pth_dl, filename)
    batch_filepaths.append(batch_filepath)
    if os.path.isfile(batch_filepath):
        print(f"\n{batch_filepath} exists\n")
        pass
    else:
        print(f"Downloading batch {index} of {len(batches)} as {batch_filepath} for:\n {(',').join(batch)}")
        osprey('parn', (',').join(batch), rptDate, rptDate, fln, 'csv')

# for batch_filepath in batch_filepaths:
#     print(batch_filepath)
# Out:
# 0it [00:00, ?it/s]
# PARN 1_of_2_CS1(94) 31Aug2026.csv, a batch of 94 files:
#    3BBCIINC, ABMMBND, ADRRC, ADVMB, ADVMM, AFGBAL, AFLBAL, AFLMMF, AFPFLB, AMMARF, AMPBQP, ASBTOS, ASHFLX, BCICEF, BCIFIF, BONMMF, BPROV, CCNPF, CCTCSH, CMPFCASH, CMPFFLEX, CMPFINC, CSIRBQP, ECICBAL, ECICBALC, ELCIPF, ENGENIP, ENGENMBF, FEMPBF, GACASH, GAEMBF, GEMSMED, GEMSMEDC, GMRETF, GMRETF2, GRFINV, GTCWP2, HOLADC, HOLDINC, HOLDINCR, HOLEQU, HOLIDC, HOLMMF, HOLYPF, HOSMED, IJGCOR, IJGIPF, IJGMMF, IMPALA, IMPBAL_C, IMPREF, IMPREF_C, IPCASH, IPIPF, ISPFP, LEZAFFI, LEZALDI, LIBTAA, LNBINS, LNBLIN, LPIIFTAA, MASAINC, MASAINRF, MASAMMF, MASASI, MASASIRF, MEDINC, MGFYQP, MOMABIL, MOMBBF, MOMBBRF, MOMFLX, MOMFXB, MOMIPF, MOMPRET, MOMTAAHI, MOMTAALI, MOMTAAMI, MULTICH, MWPFEQU, MWPFILB, MYQIP, NESEQU, NFMWAGG, NFMWEQU, NGKINC, OMLMMF, OMMAIF, PABS, PANDA, PBFETF, PBNDQ, PCBF, PCCEF
#
# Downloading batch 1 of 2 as C:\Users\hilton.netta\Downloads\PARN 1_of_2_CS1(94) 31Aug2026.csv for:
#  3BBCIINC,ABMMBND,ADRRC,ADVMB,ADVMM,AFGBAL,AFLBAL,AFLMMF,AFPFLB,AMMARF,AMPBQP,ASBTOS,ASHFLX,BCICEF,BCIFIF,BONMMF,BPROV,CCNPF,CCTCSH,CMPFCASH,CMPFFLEX,CMPFINC,CSIRBQP,ECICBAL,ECICBALC,ELCIPF,ENGENIP,ENGENMBF,FEMPBF,GACASH,GAEMBF,GEMSMED,GEMSMEDC,GMRETF,GMRETF2,GRFINV,GTCWP2,HOLADC,HOLDINC,HOLDINCR,HOLEQU,HOLIDC,HOLMMF,HOLYPF,HOSMED,IJGCOR,IJGIPF,IJGMMF,IMPALA,IMPBAL_C,IMPREF,IMPREF_C,IPCASH,IPIPF,ISPFP,LEZAFFI,LEZALDI,LIBTAA,LNBINS,LNBLIN,LPIIFTAA,MASAINC,MASAINRF,MASAMMF,MASASI,MASASIRF,MEDINC,MGFYQP,MOMABIL,MOMBBF,MOMBBRF,MOMFLX,MOMFXB,MOMIPF,MOMPRET,MOMTAAHI,MOMTAALI,MOMTAAMI,MULTICH,MWPFEQU,MWPFILB,MYQIP,NESEQU,NFMWAGG,NFMWEQU,NGKINC,OMLMMF,OMMAIF,PABS,PANDA,PBFETF,PBNDQ,PCBF,PCCEF
# (2) loading libraries
#
# Expected file name based on input values:
#    PARN 1_of_2_CS1(94) 31Aug2026.csv
# which does not yet exist in the Downloads folder.
#
# (2a) Checking if rpt_type is 'fnav', in which case, replacing '_C' in fund name
# (3) setting report suffix for .xls vs .csv
# (4) Importing the webdriver (attempt 1/5)
# (5) Starting the web driver and opening the browser ...
# (6) Browser, open sesame! ...
# (7) having logged in, opening the selected report page ...
# (7a) testing for the presence of an alert and accepting it if it exists
# (8) switching to the query page ...
# (9) updating the FROM calendar ...
# (10) updating the TO calendar, if it exists ...
# (11) getting the web element for the FUND LIST and assigning values to it ...
# (12) clicking 'Entity ID' to trigger the report generation ...
# (12a) testing for the presence of an authentication alert after clicking Submit ...
# (13) getting the web element of the 'Submit' button and then clicking it ...
# (13a) testing for the presence of an authentication alert after clicking Submit ...
# (14) waiting for and then clicking the export button ...
#   Waited 28.8sec for the export format button to be clickable and then clicked it ...
# (14a) Waiting for and then clicking the export format button ...
#   Waited 51.4sec for the download button to be clickable and then clicked it ...
# (14b) waiting for the download to complete ...
#   Download completed after 2.0sec
# (14c) renaming the downloaded file ...
#   Downloaded and renamed to: PARN 1_of_2_CS1(94) 31Aug2026
# (14d) closing the web driver ...
#
# Downloaded PARN 1_of_2_CS1(94) 31Aug2026.csv
#
# 2min 20.2sec run time
# 1it [02:24, 144.30s/it]
# PARN 2_of_2_CS1(94) 31Aug2026.csv, a batch of 94 files:
#    PCEQTF, PCGEARF, PCGEF, PCMMF, PCSHQ, PEQ, PEQF, PETFIP, PEYF, PFFIF, PGARFF, PGBEUR, PGBF, PGBGBP, PGBZAR, PGCBF, PGCEF, PGEMZAR, PGIF, PGIP_I, PGIPFA, PGIPZAR, PGPCEM_C, PGPCGE_C, PGPCZAR, PGPGARF, PGPGBF_C, PGPGIF_C, PGPRF_C, PGPRGBP, PICPROV, PIF, PIMBAL, PIMEVO, PIMIDF, PIPF, PIPFP, PLMED, PLPRNA, PMMF, POIF_C, POIFEQT, PORFIP, PPEF, PPOS, PPSBAL, PPSBAL_C, PPSFLEX, PPSNAM, PPSRBNQ, PPWEQU, PRLMMF, PRPABF, PRPDBF, PSGBF, PSIF, PSILB, PSPAM, PSSPFEQU, PSTIF, PTIF, PWMIPF_P, QIFFGIF, SAAMCAU, SAAMINC, SAAMMOD, SABCCSHF, SASRMM, SDINCPM, SILAIF, SILEQF, SISLP, SISMMF, SMMAIF, SMMIBF, SMMILP, SMMRRF, SNPFEQU, SSLSP, STBFIP, SYMMMF, TRFINC, TRFWLTH, UCT3YQ, UCTINC, UCTRFBAL, UCTRFINC, UNISABAL, UNVFRS, UOZMMF, USAIPF, UWRFCON, UWRFGRO, VMPTAA_C
#
# Downloading batch 2 of 2 as C:\Users\hilton.netta\Downloads\PARN 2_of_2_CS1(94) 31Aug2026.csv for:
#  PCEQTF,PCGEARF,PCGEF,PCMMF,PCSHQ,PEQ,PEQF,PETFIP,PEYF,PFFIF,PGARFF,PGBEUR,PGBF,PGBGBP,PGBZAR,PGCBF,PGCEF,PGEMZAR,PGIF,PGIP_I,PGIPFA,PGIPZAR,PGPCEM_C,PGPCGE_C,PGPCZAR,PGPGARF,PGPGBF_C,PGPGIF_C,PGPRF_C,PGPRGBP,PICPROV,PIF,PIMBAL,PIMEVO,PIMIDF,PIPF,PIPFP,PLMED,PLPRNA,PMMF,POIF_C,POIFEQT,PORFIP,PPEF,PPOS,PPSBAL,PPSBAL_C,PPSFLEX,PPSNAM,PPSRBNQ,PPWEQU,PRLMMF,PRPABF,PRPDBF,PSGBF,PSIF,PSILB,PSPAM,PSSPFEQU,PSTIF,PTIF,PWMIPF_P,QIFFGIF,SAAMCAU,SAAMINC,SAAMMOD,SABCCSHF,SASRMM,SDINCPM,SILAIF,SILEQF,SISLP,SISMMF,SMMAIF,SMMIBF,SMMILP,SMMRRF,SNPFEQU,SSLSP,STBFIP,SYMMMF,TRFINC,TRFWLTH,UCT3YQ,UCTINC,UCTRFBAL,UCTRFINC,UNISABAL,UNVFRS,UOZMMF,USAIPF,UWRFCON,UWRFGRO,VMPTAA_C
# (2) loading libraries
#
# Expected file name based on input values:
#    PARN 2_of_2_CS1(94) 31Aug2026.csv
# which does not yet exist in the Downloads folder.
#
# (2a) Checking if rpt_type is 'fnav', in which case, replacing '_C' in fund name
# (3) setting report suffix for .xls vs .csv
# (4) Importing the webdriver (attempt 1/5)
# (5) Starting the web driver and opening the browser ...
# (6) Browser, open sesame! ...
# (7) having logged in, opening the selected report page ...
# (7a) testing for the presence of an alert and accepting it if it exists
# (8) switching to the query page ...
# (9) updating the FROM calendar ...
# (10) updating the TO calendar, if it exists ...
# (11) getting the web element for the FUND LIST and assigning values to it ...
# (12) clicking 'Entity ID' to trigger the report generation ...
# (12a) testing for the presence of an authentication alert after clicking Submit ...
# (13) getting the web element of the 'Submit' button and then clicking it ...
# (13a) testing for the presence of an authentication alert after clicking Submit ...
# (14) waiting for and then clicking the export button ...
#   Waited 37.1sec for the export format button to be clickable and then clicked it ...
# (14a) Waiting for and then clicking the export format button ...
#   Waited 6.3sec for the download button to be clickable and then clicked it ...
# (14b) waiting for the download to complete ...
#   Download completed after 10.1sec
# (14c) renaming the downloaded file ...
#   Downloaded and renamed to: PARN 2_of_2_CS1(94) 31Aug2026
# (14d) closing the web driver ...
#
# Downloaded PARN 2_of_2_CS1(94) 31Aug2026.csv
#
# 1min 50.8sec run time
# 2it [04:19, 129.59s/it]

# %%
print('\n\n#########################################')
print('#                                       #')
print('#    END cs1_PARN_download_csv.ipynb    #')
print('#                                       #')
print('#########################################\n\n')
# Out:
# #########################################
# #                                       #
# #    END cs1_PARN_download_csv.ipynb    #
# #                                       #
# #########################################

# %%
# !jupyter nbconvert --to script cs1_PARN_download_csv.ipynb # convert from .ipynb to .py
