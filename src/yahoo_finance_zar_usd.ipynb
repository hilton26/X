# %%
import yfinance as yf

df_fx = yf.download('USDZAR=X', start='2025-01-01')
print(df_fx.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open   Volume
# Ticker       USDZAR=X   USDZAR=X   USDZAR=X   USDZAR=X USDZAR=X
# Date
# 2025-01-02  18.820150  18.864901  18.659800  18.809299        0
# 2025-01-03  18.739599  18.811800  18.672400  18.739599        0
# 2025-01-06  18.752001  18.776699  18.432730  18.752001        0
# 2025-01-07  18.545099  18.693001  18.505501  18.545099        0
# 2025-01-08  18.683300  18.955400  18.665400  18.683300        0

# %%
df_fx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 317 entries, 2025-01-02 to 2026-03-26
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Close, USDZAR=X)   317 non-null    float64
#  1   (High, USDZAR=X)    317 non-null    float64
#  2   (Low, USDZAR=X)     317 non-null    float64
#  3   (Open, USDZAR=X)    317 non-null    float64
#  4   (Volume, USDZAR=X)  317 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 14.9 KB
