# %% [markdown]
# # Download and Merge Eagle Lookthrough Sheets

# %% [markdown]
# ### Input:
#
# \\PIM-CPT-FS.prescient.local\PIM-Documents$\Investment Operations\GRC\Compliance\Daily\py_reports, "downloader" and "creds" tabs
#
# ### Dependencies:
# C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/eagle_LT_downloading.ipynb
#
# C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/eagle_LT_merge.ipynb

# %%
# create a time difference function
import time, datetime

def timediff(start, end, decimals = 1):
    if   int((end - start) / 3600) > 0: # non-zero hours
        return str(int(  (end - start) / 3600))           + 'hr '  + \
               str(int(  (end - start) /   60))           + 'min ' + \
               str(round((end - start) %   60, decimals)) + 'sec'
    elif int((end - start) /   60) > 0: # non-zero hours and minutes
        return str(int(  (end - start) /   60))           + 'min ' + \
               str(round((end - start) %   60, decimals)) + 'sec'
    else:
        return str(round((end - start) %   60, decimals)) + 'sec'

# %%
print('Downloading and merging lookthrough reports ...', '\n')
start_time          = time.time()

# https://stackoverflow.com/questions/20186344/importing-an-ipynb-file-from-another-ipynb-file   
#%run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/eagle_LT_downloading_merge.ipynb"
# %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/eagle_LT_downloading_save_merge.ipynb"
# %run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/eagle_LT_merge.ipynb"

print(f'Downloading and merging lookthrough reports completed: {timediff(start_time0, time.time())}')
# Out:
# Downloading and merging lookthrough reports ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:716, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     715     fpath = arg_lst[0]
# --> 716     filename = file_finder(fpath)
#     717 except IndexError as e:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\IPython\utils\path.py:90, in get_py_filename(name)
#      89         return py_name
# ---> 90 raise IOError("File `%r` not found." % name)
#
# OSError: File `'C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/eagle_LT_downloading_save_merge.ipynb'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 6
#       2 start_time          = time.time()
#       4 # https://stackoverflow.com/questions/20186344/importing-an-ipynb-file-from-another-ipynb-file
#       5 #%run "C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/eagle_LT_downloading_merge.ipynb"
# ----> 6 get_ipython().run_line_magic('run', '"C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/eagle_LT_downloading_save_merge.ipynb"')
#       7 get_ipython().run_line_magic('run', '"C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/eagle_LT_merge.ipynb"')
#       9 print(f'Downloading and merging lookthrough reports completed: {timediff(start_time0, time.time())}')
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2456, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2454     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2455 with self.builtin_trap:
# -> 2456     result = fn(*args, **kwargs)
#    2458 # The code below prevents the output from being displayed
#    2459 # when using magics with decorator @output_can_be_silenced
#    2460 # when the last Python token in the expression is a ';'.
#    2461 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\IPython\core\magics\execution.py:727, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     725     if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     726         warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 727     raise Exception(msg) from e
#     728 except TypeError:
#     729     if fpath in sys.meta_path:
#
# Exception: File `'C:/Users/hilton.netta/OneDrive - Prescient/py/gitrepo/eagle_LT_downloading_save_merge.ipynb'` not found.

# %%
# dataframes    :example, no_issuer, no_CLN_issuer
# input file   P:\Investment Operations\GRC\Compliance\Daily\py_reports.xlsm
# structures   P:\Working Folders\Hilton\W\structures.xlsm
# results      P:\Working Folders\Hilton\W\Reg_Tests\issuers_1.xlsx
# output       P:\Working Folders\Hilton\W\Reg_Tests\issuers_2.xlsx
# classified   P:\Working Folders\Hilton\W\Reg_Tests\issuers_3.xlsx
# merged       P:\Working Folders\Hilton\W\Reg_Tests\merged.xlsx
# Reg 28 & 30  P:\Investment Operations\GRC\Compliance\Reg28 and Reg30 Reporting
# folder       P:\Working Folders\Hilton\W\Reg_Tests
