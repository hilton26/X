# %%
from datetime import datetime

def time_diff(start_time, end_time):
    format_str       = '%Y-%m-%d %H:%M:%S.%f'
    time_difference  = end_datetime - start_datetime
    days             = time_difference.days
    hours, remainder = divmod(time_difference.seconds, 3600)
    minutes, seconds = divmod(remainder, 60)
    return f'{days}d {hours}hr {minutes}min {seconds:.1f}sec' # to one (:.1f) decimal

# %%
# Example
start = '2022-12-04 08:56:12.4'
end   = '2023-07-19 14:37:40.3'
timediff(start, end)
# Out:
# '227d 5hr 41min 27.0sec'

# %%
# Example
from datetime import datetime
strt = datetime.now()

# %%
nd   = datetime.now()

# %%
print('', strt,'\n',nd)
# Out:
#  2024-02-22 16:15:43.868593
#  2024-02-22 16:15:44.589972

# %%
time_diff(strt, nd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 time_diff(strt, nd)
#
# Cell In[64], line 5, in time_diff(start_time, end_time)
#       3 def time_diff(start_time, end_time):
#       4     format_str       = '%Y-%m-%d %H:%M:%S.%f'
# ----> 5     time_difference  = end_datetime - start_datetime
#       6     days             = time_difference.days
#       7     hours, remainder = divmod(time_difference.seconds, 3600)
#
# NameError: name 'end_datetime' is not defined

# %%
format_str       = '%Y-%m-%d %H:%M:%S.%f'
k = strt.strftime(format_str)
k
# Out:
# '2024-02-22 16:06:58.085637'

# %%
nd - strt
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 nd - strt
#
# TypeError: unsupported operand type(s) for -: 'float' and 'datetime.datetime'

# %%
time_diff(strt,nd)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 time_diff(strt,nd)
#
# Cell In[28], line 11, in time_diff(start_time, end_time)
#       9     end_datetime   = end_time
#      10 time_difference  = end_datetime - start_datetime
# ---> 11 days             = time_difference.days
#      12 hours, remainder = divmod(time_difference.seconds, 3600)
#      13 minutes, seconds = divmod(remainder, 60)
#
# AttributeError: 'float' object has no attribute 'days'

# %%
strt
# Out:
# 1708597156.899856

# %%
nd
# Out:
# 1708597239.5623498
